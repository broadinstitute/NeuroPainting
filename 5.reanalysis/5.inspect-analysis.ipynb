# %% [markdown]
# # Analysis

# %% [markdown]
# ## Imports

# %%
import sys
import os
import pandas as pd

# Get the current working directory of the notebook
notebook_dir = os.path.abspath(os.getcwd())

# Construct the path to the 'src' directory
ncp_src_path = os.path.abspath(os.path.join(notebook_dir, "..", "ncp", "src"))

# Add the 'src' directory to sys.path
if ncp_src_path not in sys.path:
    sys.path.append(ncp_src_path)

# Now you can import the modules
from visualization import visualize_results

# Suppressing warnings for cleaner output
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Control vs Deletion, per cell type

# %%
results_file = "output/analysis_results/control_vs_deletion/summary_results.parquet"

# %%
visualize_results(
    input_file=results_file,
)
# Out:
# Category: stem
# Logistic Regression Accuracy Score: 0.7931
# Number of Significant Features: 20
# ======================================================================
#
# Category: progen
# Logistic Regression Accuracy Score: 0.7212
# Number of Significant Features: 23
# ======================================================================
#
# Category: neuron
# Logistic Regression Accuracy Score: 0.5233
# Number of Significant Features: 0
# ======================================================================
#
# Category: astro
# Logistic Regression Accuracy Score: 0.7339
# Number of Significant Features: 23
# ======================================================================

# %% [markdown]
# ## Cell type A vs B

# %%
from itertools import combinations

# Define the cell types
cell_types = ["stem", "neuron", "progen", "astro"]

# Create all unique pairs of cell types
cell_type_pairs = list(combinations(cell_types, 2))

for cell_type_0, cell_type_1 in cell_type_pairs:
    # Define the input directory based on the current pair
    input_dir = (
        f"output/analysis_results/cell_type_a_vs_b/{cell_type_0}_vs_{cell_type_1}/"
    )
    print(f"{cell_type_0}_vs_{cell_type_1}")
    visualize_results(input_file=f"{input_dir}/summary_results.parquet")
# Out:
# stem_vs_neuron
#
# Category: control
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 28
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9983
# Number of Significant Features: 28
# ======================================================================
# stem_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 30
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9944
# Number of Significant Features: 29
# ======================================================================
# stem_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 30
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 28
# ======================================================================
# neuron_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9900
# Number of Significant Features: 26
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9858
# Number of Significant Features: 25
# ======================================================================
# neuron_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9950
# Number of Significant Features: 28
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 26
# ======================================================================
# progen_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9966
# Number of Significant Features: 24
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9933
# Number of Significant Features: 26
# ======================================================================
