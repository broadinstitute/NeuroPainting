# %% [markdown]
# # Inspect analysis

# %%
import sys
import os

notebook_dir = os.path.abspath(os.getcwd())

ncp_src_path = os.path.abspath(os.path.join(notebook_dir, "..", "ncp", "src"))

if ncp_src_path not in sys.path:
    sys.path.append(ncp_src_path)

from utils import inspect_analysis

# Suppressing warnings for cleaner output
import warnings

warnings.filterwarnings("ignore")

# %%
data_level = "normalized_feature_select"

inspect_analysis(data_level)
# Out:
# Category: progen
# Logistic Regression Accuracy Score: 0.7885
# Number of Significant Features: 439
# ======================================================================
#
# Category: neuron
# Logistic Regression Accuracy Score: 0.6000
# Number of Significant Features: 246
# ======================================================================
#
# Category: stem
# Logistic Regression Accuracy Score: 0.8854
# Number of Significant Features: 644
# ======================================================================
#
# Category: astro
# Logistic Regression Accuracy Score: 0.7806
# Number of Significant Features: 627
# ======================================================================
# normalized_feature_select:stem_vs_neuron
#
# Category: control
# Logistic Regression Accuracy Score: 0.9646
# Number of Significant Features: 606
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9583
# Number of Significant Features: 517
# ======================================================================
# normalized_feature_select:stem_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9481
# Number of Significant Features: 606
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9125
# Number of Significant Features: 438
# ======================================================================
# normalized_feature_select:stem_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9689
# Number of Significant Features: 484
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.8500
# Number of Significant Features: 344
# ======================================================================
# normalized_feature_select:neuron_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9546
# Number of Significant Features: 97
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9467
# Number of Significant Features: 390
# ======================================================================
# normalized_feature_select:neuron_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9543
# Number of Significant Features: 563
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.8350
# Number of Significant Features: 398
# ======================================================================
# normalized_feature_select:progen_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9435
# Number of Significant Features: 560
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.8717
# Number of Significant Features: 477
# ======================================================================

# %%
data_level = "var_mad_int_featselect"

inspect_analysis(data_level)
# Out:
# Category: progen
# Logistic Regression Accuracy Score: 0.8156
# Number of Significant Features: 387
# ======================================================================
#
# Category: neuron
# Logistic Regression Accuracy Score: 0.5589
# Number of Significant Features: 224
# ======================================================================
#
# Category: stem
# Logistic Regression Accuracy Score: 0.9069
# Number of Significant Features: 567
# ======================================================================
#
# Category: astro
# Logistic Regression Accuracy Score: 0.9118
# Number of Significant Features: 536
# ======================================================================
# var_mad_int_featselect:stem_vs_neuron
#
# Category: control
# Logistic Regression Accuracy Score: 0.9550
# Number of Significant Features: 525
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9213
# Number of Significant Features: 459
# ======================================================================
# var_mad_int_featselect:stem_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9187
# Number of Significant Features: 529
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9187
# Number of Significant Features: 382
# ======================================================================
# var_mad_int_featselect:stem_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9191
# Number of Significant Features: 421
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9208
# Number of Significant Features: 296
# ======================================================================
# var_mad_int_featselect:neuron_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9354
# Number of Significant Features: 85
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.8721
# Number of Significant Features: 334
# ======================================================================
# var_mad_int_featselect:neuron_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9582
# Number of Significant Features: 480
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9425
# Number of Significant Features: 337
# ======================================================================
# var_mad_int_featselect:progen_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9244
# Number of Significant Features: 481
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9533
# Number of Significant Features: 407
# ======================================================================
