# %% [markdown]
# # Inspect analysis

# %%
import sys
import os

notebook_dir = os.path.abspath(os.getcwd())

ncp_src_path = os.path.abspath(os.path.join(notebook_dir, "..", "ncp", "src"))

if ncp_src_path not in sys.path:
    sys.path.append(ncp_src_path)

from utils import inspect_analysis

# Suppressing warnings for cleaner output
import warnings

warnings.filterwarnings("ignore")

# %%
data_level = "augmented"

inspect_analysis(data_level)
# Out:
# Category: stem
# Logistic Regression Accuracy Score: 0.8389
# Number of Significant Features: 24
# ======================================================================
#
# Category: progen
# Logistic Regression Accuracy Score: 0.7090
# Number of Significant Features: 23
# ======================================================================
#
# Category: neuron
# Logistic Regression Accuracy Score: 0.5458
# Number of Significant Features: 1
# ======================================================================
#
# Category: astro
# Logistic Regression Accuracy Score: 0.8002
# Number of Significant Features: 27
# ======================================================================
# augmented:stem_vs_neuron
#
# Category: control
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 26
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9983
# Number of Significant Features: 26
# ======================================================================
# augmented:stem_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9875
# Number of Significant Features: 30
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 30
# ======================================================================
# augmented:stem_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 29
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 28
# ======================================================================
# augmented:neuron_vs_progen
#
# Category: control
# Logistic Regression Accuracy Score: 0.9979
# Number of Significant Features: 29
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 29
# ======================================================================
# augmented:neuron_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 1.0000
# Number of Significant Features: 24
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9975
# Number of Significant Features: 26
# ======================================================================
# augmented:progen_vs_astro
#
# Category: control
# Logistic Regression Accuracy Score: 0.9958
# Number of Significant Features: 27
# ======================================================================
#
# Category: deletion
# Logistic Regression Accuracy Score: 0.9917
# Number of Significant Features: 28
# ======================================================================
