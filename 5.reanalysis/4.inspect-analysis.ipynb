# %% [markdown]
# # Analysis

# %% [markdown]
# ## Imports

# %%
import sys
import os
import pandas as pd

# Get the current working directory of the notebook
notebook_dir = os.path.abspath(os.getcwd())

# Construct the path to the 'src' directory
ncp_src_path = os.path.abspath(os.path.join(notebook_dir, "..", "ncp", "src"))

# Add the 'src' directory to sys.path
if ncp_src_path not in sys.path:
    sys.path.append(ncp_src_path)

# Now you can import the modules
from visualization import load_and_print_results


# Suppressing warnings for cleaner output
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Control vs Deletion, per cell type

# %%
results_file = "output/analysis_results/control_vs_deletion/summary_results.parquet"

# %%
results = pd.read_parquet(results_file)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=results,
    x="logistic_regression_accuracy",
    y="num_significant_features",
    hue="category",
    palette="deep",
    s=100,
)

plt.title("Logistic Regression Accuracy vs Number of Significant Features")
plt.xlabel("Logistic Regression Accuracy")
plt.ylabel("Number of Significant Features")

# Show the plot
plt.show()

# %%
load_and_print_results(
    input_file=results_fileresults,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/shsingh/work/projects/2019_05_28_Neuronal_Cell_Painting/workspace/software/neuronal-cell-painting/5.reanalysis/4.inspect-analysis.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/Users/shsingh/work/projects/2019_05_28_Neuronal_Cell_Painting/workspace/software/neuronal-cell-painting/5.reanalysis/4.inspect-analysis.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> load_and_print_results(
# ----> <a href='vscode-notebook-cell:/Users/shsingh/work/projects/2019_05_28_Neuronal_Cell_Painting/workspace/software/neuronal-cell-painting/5.reanalysis/4.inspect-analysis.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     input_file=results_fileresults,
# ...

# %% [markdown]
# ## Cell type A vs B

# %%
from itertools import combinations

# Define the cell types
cell_types = ["stem", "neuron", "progen", "astro"]

# Create all unique pairs of cell types
cell_type_pairs = list(combinations(cell_types, 2))

for cell_type_0, cell_type_1 in cell_type_pairs:
    # Define the input directory based on the current pair
    input_dir = (
        f"output/analysis_results/cell_type_a_vs_b/{cell_type_0}_vs_{cell_type_1}/"
    )
    print(f"{cell_type_0}_vs_{cell_type_1}")
    load_and_print_results(input_file=f"{input_dir}/summary_results.parquet")
