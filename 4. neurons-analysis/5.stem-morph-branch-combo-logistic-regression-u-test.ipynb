# %% [markdown]
# #### Yu Han, Nov 2022.
# We used logistic regression to classify stem cells with deletion vs. w/o deletion. Feature importance score is printed.
#
# mann-whitney-u-test was adopted to run feature by feature analysis between the deletion group and the control group to find significant features.
#
# Combining morph features and branching features.

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import math
import statistics
import random
import scipy.stats as ss

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupShuffleSplit

import warnings
warnings.filterwarnings("ignore")
from pycytominer import aggregate

# %% [markdown]
# ### logistic regression

# %%
#read morph feature profile data of two plates 
df_stem=pd.read_csv('../1.run-workflows/profiles/NCP_STEM_1/BR_NCP_STEM_1/BR_NCP_STEM_1_normalized_variable_selected.csv.gz')
df_stem.head(2)
# Out:
#   Metadata_Plate Metadata_Well Metadata_Assay_Plate_Barcode  \
# 0  BR_NCP_STEM_1           A01                BR_NCP_STEM_1
# 1  BR_NCP_STEM_1           A02                BR_NCP_STEM_1
#
#   Metadata_Plate_Map_Name Metadata_well_position  Metadata_plating_density  \
# 0           BR_NCP_STEM_1                    A01                     10000
# 1           BR_NCP_STEM_1                    A02                     10000
#
#    Metadata_line_ID Metadata_line_condition Metadata_line_source  \
# 0                 1                 control                human
# 1                 1                 control                human
#
#    Cells_AreaShape_Center_X  ...  Nuclei_Texture_InfoMeas1_RNA_10_03  \
# 0                   0.50933  ...                            -0.90823
# 1                  -0.31877  ...                            -1.63920
#
#    Nuclei_Texture_InfoMeas2_Brightfield_20_00  \
# 0                                     1.56270
# 1                                     0.65012
#
#    Nuclei_Texture_InfoMeas2_ER_10_03  Nuclei_Texture_InfoMeas2_RNA_10_03  \
# 0                             1.1817                             0.17543
# 1                             1.2649                             1.45140
#
#    Nuclei_Texture_InfoMeas2_RNA_20_01  \
# 0                            0.000126
# 1                            0.280320
#
#    Nuclei_Texture_InverseDifferenceMoment_ER_20_02  \
# 0                                         -0.89288
# 1                                         -1.23480
#
#    Nuclei_Texture_SumAverage_Brightfield_20_03  \
# 0                                     0.630330
# 1                                    -0.062683
#
#    Nuclei_Texture_SumEntropy_Brightfield_20_01  \
# 0                                      0.63990
# 1                                     -0.26259
#
#    Nuclei_Texture_SumVariance_DNA_20_03  Nuclei_Texture_SumVariance_Mito_10_00
# 0                                2.8473                                0.82266
# 1                                2.7774                                0.43155
#
# [2 rows x 423 columns]

# %%
#code deletion as 1 and control as 0. 
df_stem.Metadata_line_condition[df_stem.Metadata_line_condition == 'deletion'] = 1
df_stem.Metadata_line_condition[df_stem.Metadata_line_condition == 'control'] = 0

# %%
#select all feature columns
df_stem_feature=df_stem.loc[:,~df_stem.columns.str.startswith('Metadata')]

# %%
### logistic regression 
#define X and y
X=df_stem_feature.values
y=df_stem['Metadata_line_condition'].tolist()
y0=np.array(y)

#split training and testing 
#using GroupShuffleSplit to ensure the same patient won't appear in train and test set at the same time
gss = GroupShuffleSplit(n_splits=2, train_size=.8, random_state=42)
gss.get_n_splits()
for train_idx, test_idx in gss.split(X, y0, df_stem['Metadata_line_ID']):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y0[train_idx], y0[test_idx]

#fit the model
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, y_train)
predictions = logisticRegr.predict(X_test)

#print acc score
score = logisticRegr.score(X_test, y_test)
score
# Out:
# 0.85

# %%
#print feature importance values
stem_feature_weights = pd.DataFrame(logisticRegr.coef_[0], columns=['weight'], index=df_stem_feature.columns)
stem_feature_weights.reindex(stem_feature_weights['weight'].abs().sort_values(ascending=False).index).head(10)
# Out:
#                                                       weight
# Cytoplasm_Intensity_MADIntensity_ER                 0.470532
# Cytoplasm_RadialDistribution_FracAtD_Brightfiel...  0.456733
# Cytoplasm_Granularity_1_ER                         -0.435410
# Cytoplasm_Texture_AngularSecondMoment_ER_5_03      -0.422814
# Nuclei_Correlation_Costes_Mito_AGP                 -0.408511
# Cytoplasm_RadialDistribution_FracAtD_ER_1of4        0.370923
# Nuclei_Correlation_Correlation_DNA_Brightfield      0.337267
# Nuclei_Texture_InfoMeas1_DNA_10_03                  0.335631
# Cytoplasm_Texture_InverseDifferenceMoment_ER_5_00  -0.334789
# Cytoplasm_Correlation_Overlap_ER_AGP                0.334526

# %% [markdown]
# ### mann-whitney-u-test

# %%
#mean profile based on patient ID and genotype
df_stem_mean= aggregate(
                    population_df=df_stem, 
                    strata=['Metadata_line_ID', 'Metadata_line_condition'], 
                    features='infer', 
                    operation='mean' 
                    )
df_stem_mean.head(2)
# Out:
#    Metadata_line_ID  Metadata_line_condition  Cells_AreaShape_Center_X  \
# 0                 1                        0                   0.33765
# 1                 2                        0                   0.20346
#
#    Cells_AreaShape_Eccentricity  Cells_AreaShape_MedianRadius  \
# 0                     -1.014609                      1.115119
# 1                     -1.506153                     -0.656129
#
#    Cells_AreaShape_Zernike_2_0  Cells_AreaShape_Zernike_3_1  \
# 0                     0.224115                    -0.771190
# 1                     0.644070                    -1.084775
#
#    Cells_AreaShape_Zernike_4_0  Cells_AreaShape_Zernike_4_2  \
# 0                     1.167344                    -1.538127
# 1                    -0.466943                    -0.949160
#
#    Cells_AreaShape_Zernike_5_1  ...  Nuclei_Texture_InfoMeas1_RNA_10_03  \
# 0                     0.008333  ...                           -0.177020
# 1                    -0.948195  ...                            0.063658
#
#    Nuclei_Texture_InfoMeas2_Brightfield_20_00  \
# 0                                    0.795322
# 1                                    0.072330
#
#    Nuclei_Texture_InfoMeas2_ER_10_03  Nuclei_Texture_InfoMeas2_RNA_10_03  \
# 0                            0.45881                            0.377981
# 1                           -0.22361                           -0.078084
#
#    Nuclei_Texture_InfoMeas2_RNA_20_01  \
# 0                            0.415751
# 1                           -0.560149
#
#    Nuclei_Texture_InverseDifferenceMoment_ER_20_02  \
# 0                                        -0.157851
# 1                                        -0.837804
#
#    Nuclei_Texture_SumAverage_Brightfield_20_03  \
# 0                                     0.490920
# 1                                    -0.449675
#
#    Nuclei_Texture_SumEntropy_Brightfield_20_01  \
# 0                                     0.523019
# 1                                    -0.158889
#
#    Nuclei_Texture_SumVariance_DNA_20_03  Nuclei_Texture_SumVariance_Mito_10_00
# 0                              1.778150                               0.696038
# 1                              0.507883                               0.088082
#
# [2 rows x 416 columns]

# %%
#select all feature columns
df_stem_feature_u=df_stem_mean.loc[:,~df_stem_mean.columns.str.startswith('Metadata')]

# %%
#create feature list
feature_list=list(df_stem_feature_u.columns)

# %%
#create empty dataframe
df_p_values_feature = pd.DataFrame(index=[0],columns=feature_list)

# %%
#run mann-whitney-u test
list_p = []
list_u = []
for feat in feature_list:
    u, p = ss.mannwhitneyu(df_stem_mean.query('Metadata_line_condition == 1')[feat],          
           df_stem_mean.query('Metadata_line_condition == 0')[feat])
    list_p.append(p)
    list_u.append(u)

# %%
#store p value to each feature
df_p_values_feature.iloc[0] =list_p
df_p_values_feature
# Out:
#   Cells_AreaShape_Center_X Cells_AreaShape_Eccentricity  \
# 0                0.0407227                     0.271501
#
#   Cells_AreaShape_MedianRadius Cells_AreaShape_Zernike_2_0  \
# 0                    0.0181793                    0.174072
#
#   Cells_AreaShape_Zernike_3_1 Cells_AreaShape_Zernike_4_0  \
# 0                  0.00134919                  0.00214628
#
#   Cells_AreaShape_Zernike_4_2 Cells_AreaShape_Zernike_5_1  \
# 0                    0.471234                 0.000503016
#
#   Cells_AreaShape_Zernike_5_3 Cells_AreaShape_Zernike_6_0  ...  \
# 0                    0.321345                  0.00126063  ...
#
#   Nuclei_Texture_InfoMeas1_RNA_10_03  \
# 0                           0.139508
#
#   Nuclei_Texture_InfoMeas2_Brightfield_20_00  \
# 0                                  0.0269314
#
#   Nuclei_Texture_InfoMeas2_ER_10_03 Nuclei_Texture_InfoMeas2_RNA_10_03  \
# 0                          0.122007                          0.0648173
#
#   Nuclei_Texture_InfoMeas2_RNA_20_01  \
# 0                           0.299513
#
#   Nuclei_Texture_InverseDifferenceMoment_ER_20_02  \
# 0                                         0.43855
#
#   Nuclei_Texture_SumAverage_Brightfield_20_03  \
# 0                                    0.153705
#
#   Nuclei_Texture_SumEntropy_Brightfield_20_01  \
# 0                                   0.0464299
#
#   Nuclei_Texture_SumVariance_DNA_20_03 Nuclei_Texture_SumVariance_Mito_10_00
# 0                            0.0730168                           2.32675e-05
#
# [1 rows x 414 columns]

# %%
#select features with p value smaller than .05
df_p_values_feature= df_p_values_feature.drop(df_p_values_feature.
                         columns[df_p_values_feature.iloc[-1,:]>0.001],axis=1)
df_p_values_feature.columns
# Out:
# Index(['Cells_AreaShape_Zernike_5_1', 'Cells_AreaShape_Zernike_7_1',
#        'Cells_AreaShape_Zernike_8_0', 'Cells_AreaShape_Zernike_8_2',
#        'Cells_AreaShape_Zernike_9_1', 'Cells_Correlation_Correlation_DNA_ER',
#        'Cells_Correlation_Correlation_DNA_RNA',
#        'Cells_Correlation_Correlation_ER_AGP', 'Cells_Correlation_K_RNA_DNA',
#        'Cells_Correlation_Overlap_DNA_Mito',
#        'Cells_Correlation_Overlap_DNA_RNA', 'Cells_Correlation_Overlap_ER_AGP',
#        'Cells_Correlation_Overlap_ER_RNA', 'Cells_Granularity_10_AGP',
#        'Cells_Granularity_2_AGP', 'Cells_Granularity_2_RNA',
#        'Cells_Intensity_IntegratedIntensityEdge_Mito',
#        'Cells_Intensity_MADIntensity_DNA',
#        'Cells_Intensity_MassDisplacement_Mito',
#        'Cells_Intensity_MeanIntensityEdge_AGP',
#        'Cells_Intensity_MinIntensity_RNA',
#        'Cells_Intensity_StdIntensityEdge_AGP',
#        'Cells_Intensity_StdIntensityEdge_ER',
#        'Cells_Neighbors_FirstClosestDistance_Adjacent',
#        'Cells_RadialDistribution_MeanFrac_Brightfield_1of4',
#        'Cells_RadialDistribution_MeanFrac_DNA_3of4',
#        'Cells_RadialDistribution_MeanFrac_ER_1of4',
#        'Cells_RadialDistribution_RadialCV_AGP_1of4',
#        'Cells_RadialDistribution_RadialCV_DNA_3of4',
#        'Cells_RadialDistribution_RadialCV_DNA_4of4',
#        'Cells_RadialDistribution_RadialCV_RNA_1of4',
#        'Cells_Texture_InfoMeas1_RNA_5_02', 'Cytoplasm_Correlation_K_AGP_ER',
#        'Cytoplasm_Correlation_K_AGP_RNA',
#        'Cytoplasm_Correlation_K_Mito_Brightfield',
#        'Cytoplasm_Correlation_Overlap_DNA_ER',
#        'Cytoplasm_Correlation_Overlap_DNA_Mito',
#        'Cytoplasm_Correlation_Overlap_DNA_RNA',
#        'Cytoplasm_Correlation_Overlap_ER_AGP',
#        'Cytoplasm_Correlation_Overlap_Mito_Brightfield',
#        'Cytoplasm_Correlation_Overlap_Mito_RNA',
#        'Cytoplasm_Granularity_1_Brightfield', 'Cytoplasm_Granularity_2_ER',
#        'Cytoplasm_Granularity_5_AGP', 'Cytoplasm_Granularity_7_ER',
#        'Cytoplasm_Intensity_IntegratedIntensityEdge_ER',
#        'Cytoplasm_Intensity_MADIntensity_ER',
#        'Cytoplasm_Intensity_MedianIntensity_Mito',
#        'Cytoplasm_RadialDistribution_FracAtD_Brightfield_1of4',
#        'Cytoplasm_RadialDistribution_RadialCV_AGP_1of4',
#        'Cytoplasm_Texture_InfoMeas1_DNA_20_03',
#        'Nuclei_Children_Cytoplasm_Count',
#        'Nuclei_Correlation_Correlation_DNA_Brightfield',
#        'Nuclei_Correlation_K_DNA_RNA', 'Nuclei_Correlation_K_RNA_DNA',
#        'Nuclei_Correlation_Overlap_ER_AGP',
#        'Nuclei_Correlation_Overlap_Mito_RNA', 'Nuclei_Granularity_12_Mito',
#        'Nuclei_Granularity_2_AGP', 'Nuclei_Granularity_2_ER',
#        'Nuclei_Granularity_3_DNA', 'Nuclei_Granularity_3_RNA',
#        'Nuclei_Granularity_4_DNA', 'Nuclei_Granularity_9_AGP',
#        'Nuclei_Neighbors_PercentTouching_2',
#        'Nuclei_RadialDistribution_MeanFrac_Mito_3of4',
#        'Nuclei_RadialDistribution_RadialCV_AGP_2of4',
#        'Nuclei_RadialDistribution_RadialCV_AGP_3of4',
#        'Nuclei_Texture_InfoMeas1_DNA_10_03',
#        'Nuclei_Texture_InfoMeas1_ER_5_00',
#        'Nuclei_Texture_SumVariance_Mito_10_00'],
#       dtype='object')
