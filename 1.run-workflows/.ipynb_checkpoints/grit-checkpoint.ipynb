# %%
# %load_ext nb_black

# %%
import pathlib
import pandas as pd
import plotnine as gg

from cytominer_eval import evaluate

# %%
# Load Data
path = pathlib.Path(
    "profiles/NCP_PILOT_3/BR_NCP_PILOT_3/BR_NCP_PILOT_3_normalized_variable_selected.csv.gz"
)

df = pd.read_csv(path)

# Define important function arguments
meta_features = df.columns[df.columns.str.startswith("Metadata_")]
features = df.drop(meta_features, axis="columns").columns.tolist()

# Metadata_group is Metadata_line_condition + Metadata_plating_density
# Metadata_replicate is Metadata_compound_ID

print(df.shape)
df.head(5)
# Out:
# (384, 666)
#    Metadata_Plate Metadata_Well Metadata_Assay_Plate_Barcode  \
# 0  BR_NCP_PILOT_3           A01               BR_NCP_PILOT_3
# 1  BR_NCP_PILOT_3           A02               BR_NCP_PILOT_3
# 2  BR_NCP_PILOT_3           A03               BR_NCP_PILOT_3
# 3  BR_NCP_PILOT_3           A04               BR_NCP_PILOT_3
# 4  BR_NCP_PILOT_3           A05               BR_NCP_PILOT_3
#
#   Metadata_Plate_Map_Name Metadata_well_position  Metadata_plating_density  \
# 0          BR_NCP_PILOT_3                    A01                      2500
# 1          BR_NCP_PILOT_3                    A02                     10000
# 2          BR_NCP_PILOT_3                    A03                      2500
# 3          BR_NCP_PILOT_3                    A04                     10000
# 4          BR_NCP_PILOT_3                    A05                      2500
#
#   Metadata_line_condition    Metadata_compound_ID      Metadata_replicate  \
# 0                 control               Untreated               Untreated
# 1                 control               Untreated               Untreated
# 2                 control  BRD-K79131256-001-17-9  BRD-K79131256-001-17-9
# 3                 control  BRD-K36207157-001-09-6  BRD-K36207157-001-09-6
# 4                 control               Untreated               Untreated
#
#   Metadata_group  ...  Neurites_Texture_InfoMeas2_RNA_20_03  \
# 0   control_2500  ...                               0.68736
# 1  control_10000  ...                               1.42290
# 2   control_2500  ...                               0.83461
# 3  control_10000  ...                               1.66050
# 4   control_2500  ...                               2.11990
#
#    Neurites_Texture_InverseDifferenceMoment_AGP_10_02  \
# 0                                            0.32353
# 1                                           -1.49340
# 2                                           -0.84041
# 3                                           -1.73520
# 4                                            1.42280
#
#    Neurites_Texture_InverseDifferenceMoment_AGP_20_02  \
# 0                                            0.38678
# 1                                           -1.79440
# 2                                           -0.30974
# 3                                           -1.53300
# 4                                            1.51170
#
#    Neurites_Texture_InverseDifferenceMoment_DNA_5_00  \
# 0                                          -1.333400
# 1                                          -0.053887
# 2                                           0.854620
# 3                                          -0.472280
# 4                                           0.554710
#
#    Neurites_Texture_SumAverage_AGP_10_00  \
# 0                                0.84262
# 1                                1.81270
# 2                                1.29650
# 3                                1.98300
# 4                               -0.27509
#
#    Neurites_Texture_SumAverage_RNA_20_00  \
# 0                                0.43418
# 1                                2.02500
# 2                                0.03451
# 3                                1.34460
# 4                               -0.17327
#
#    Neurites_Texture_SumVariance_Brightfield_10_03  \
# 0                                         2.85160
# 1                                         4.02830
# 2                                         0.90154
# 3                                         1.43450
# 4                                         0.92286
#
#    Neurites_Texture_SumVariance_DNA_20_03  \
# 0                               -0.065548
# 1                               -0.377890
# 2                               -0.094023
# 3                                0.477740
# 4                               -0.267170
#
#    Neurites_Texture_SumVariance_ER_20_03  Neurites_Texture_Variance_AGP_5_02
# 0                                1.05590                              1.8216
# 1                                1.38140                              2.0071
# 2                                0.67013                              2.7642
# 3                                1.00020                              2.0469
# 4                                0.50922                              1.2480
#
# [5 rows x 666 columns]

# %% [markdown]
# # Compute grit for each replicate

# %%
all_grit_results = []
for condition in df.Metadata_line_condition.unique():
    for plate_density in df.Metadata_plating_density.unique():
        subset_df = df.query("Metadata_line_condition == @condition").query(
            "Metadata_plating_density == @plate_density"
        )

        # First do this without any grouping (use the whole plate)
        control_perts = subset_df.query(
            "Metadata_compound_ID == 'Untreated'"
        ).Metadata_Well

        n_control_perts = control_perts.size

        print(
            f"Number of perturbations for {condition}-{plate_density}={n_control_perts}"
        )
        replicate_groups = {
            "replicate_id": "Metadata_Well",
            "group_id": "Metadata_compound_ID",
        }

        all_grit_results.append(
            evaluate(
                profiles=subset_df,
                features=features,
                meta_features=meta_features,
                replicate_groups=replicate_groups,
                operation="grit",
                grit_control_perts=control_perts,
            ).assign(condition=condition, plate_density=plate_density)
        )
# Out:
# Number of perturbations for control-2500=32
# Number of perturbations for control-10000=32
# Number of perturbations for control-5000=32
# Number of perturbations for control-7500=32
# Number of perturbations for deletion-2500=33
# Number of perturbations for deletion-10000=32
# Number of perturbations for deletion-5000=32
# Number of perturbations for deletion-7500=32

# %%
full_grit_results_df = pd.concat(all_grit_results).sort_values(
    by="grit", ascending=False
)

full_grit_results_df.plate_density = pd.Categorical(
    full_grit_results_df.plate_density.astype(str),
    categories=[str(x) for x in sorted(full_grit_results_df.plate_density.unique())],
)

print(full_grit_results_df.shape)
full_grit_results_df.head()
# Out:
# (384, 5)
#    perturbation                   group      grit condition plate_density
# 29          K11  BRD-K21680192-300-14-4  9.520959  deletion          2500
# 5           C11  BRD-K21680192-300-14-4  8.929419  deletion          2500
# 17          G11  BRD-K21680192-300-14-4  8.599148  deletion          2500
# 8           A18  BRD-K21680192-300-14-4  7.940782   control         10000
# 32          I18  BRD-K21680192-300-14-4  6.606883   control         10000

# %%
grit_compare_gg = (
    gg.ggplot(
        full_grit_results_df.query("group != 'Untreated'"),
        gg.aes(x="plate_density", y="grit", color="group"),
    )
    + gg.geom_jitter(width=0.15, size=2)
    + gg.facet_wrap("~condition")
    + gg.theme_bw()
    + gg.geom_hline(yintercept=0, linetype="dashed", color="red")
    + gg.theme(strip_background=gg.element_rect(colour="black", fill="#fdfff4"))
    + gg.ggtitle("Replicate-level grit")
)

output_file = pathlib.Path("figures/BR_NCP_PILOT_3_grit_replicate.png")
grit_compare_gg.save(output_file, dpi=500, height=3, width=6.5)

grit_compare_gg
# Out:
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 6.5 x 3 in image.
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/BR_NCP_PILOT_3_grit_replicate.png
# <ggplot: (453539280)>

# %% [markdown]
# # Aggregate replicate-level grit (using median)

# %%
full_grit_results_df_agg_median = (
    full_grit_results_df.query("group != 'Untreated'")
    .groupby(["condition", "plate_density", "group"])
    .mean()
)

full_grit_results_df_agg_mean = (
    full_grit_results_df.query("group != 'Untreated'")
    .groupby(["condition", "plate_density", "group"])
    .median()
)

# %%
grit_compare_gg = (
    gg.ggplot(
        full_grit_results_df_agg_median.reset_index().query("group != 'Untreated'"),
        gg.aes(x="plate_density", y="grit", color="group"),
    )
    + gg.geom_jitter(width=0.15, size=2)
    + gg.facet_wrap("~condition")
    + gg.theme_bw()
    + gg.geom_hline(yintercept=0, linetype="dashed", color="red")
    + gg.theme(strip_background=gg.element_rect(colour="black", fill="#fdfff4"))
    + gg.ggtitle("Replicate-level grit, aggregated (using median)")
)

output_file = pathlib.Path("figures/BR_NCP_PILOT_3_grit_replicate_aggregated_median.png")
grit_compare_gg.save(output_file, dpi=500, height=3, width=6.5)

grit_compare_gg
# Out:
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 6.5 x 3 in image.
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/BR_NCP_PILOT_3_grit_replicate_aggregated_median.png
# <ggplot: (453751721)>

# %%
grit_compare_gg = (
    gg.ggplot(
        full_grit_results_df_agg_mean.reset_index().query("group != 'Untreated'"),
        gg.aes(x="plate_density", y="grit", color="group"),
    )
    + gg.geom_jitter(width=0.15, size=2)
    + gg.facet_wrap("~condition")
    + gg.theme_bw()
    + gg.geom_hline(yintercept=0, linetype="dashed", color="red")
    + gg.theme(strip_background=gg.element_rect(colour="black", fill="#fdfff4"))
    + gg.ggtitle("Replicate-level grit, aggregated (using mean)")
)

output_file = pathlib.Path("figures/BR_NCP_PILOT_3_grit_replicate_aggregated_mean.png")
grit_compare_gg.save(output_file, dpi=500, height=3, width=6.5)

grit_compare_gg
# Out:
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 6.5 x 3 in image.
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/BR_NCP_PILOT_3_grit_replicate_aggregated_mean.png
# <ggplot: (453867514)>

# %% [markdown]
# # Compute grit for each compound

# %%
all_grit_results = []
for condition in df.Metadata_line_condition.unique():
    for plate_density in df.Metadata_plating_density.unique():
        subset_df = df.query("Metadata_line_condition == @condition").query(
            "Metadata_plating_density == @plate_density"
        )

        # First do this without any grouping (use the whole plate)
        control_perts = ["Untreated"]

        replicate_groups = {
            "replicate_id": "Metadata_compound_ID",
            "group_id": "Metadata_group",
        }

        all_grit_results.append(
            evaluate(
                profiles=subset_df,
                features=features,
                meta_features=meta_features,
                replicate_groups=replicate_groups,
                operation="grit",
                grit_control_perts=control_perts,
            ).assign(condition=condition, plate_density=plate_density)
        )

# %%
full_grit_results_df = pd.concat(all_grit_results).sort_values(
    by="grit", ascending=False
)

full_grit_results_df.plate_density = pd.Categorical(
    full_grit_results_df.plate_density.astype(str),
    categories=[str(x) for x in sorted(full_grit_results_df.plate_density.unique())],
)

print(full_grit_results_df.shape)
full_grit_results_df.head()
# Out:
# (40, 5)
#              perturbation          group      grit condition plate_density
# 1  BRD-K21680192-300-14-4  deletion_5000  0.131401  deletion          5000
# 1  BRD-K21680192-300-14-4   control_7500  0.108044   control          7500
# 2  BRD-K36207157-001-09-6  deletion_2500  0.082487  deletion          2500
# 2  BRD-K36207157-001-09-6   control_7500  0.080734   control          7500
# 1  BRD-K21680192-300-14-4  deletion_7500  0.059791  deletion          7500

# %%
grit_compare_gg = (
    gg.ggplot(
        full_grit_results_df.query("perturbation != 'Untreated'"),
        gg.aes(x="plate_density", y="grit", color="perturbation"),
    )
    + gg.geom_jitter(width=0.15, size=2)
    + gg.facet_wrap("~condition")
    + gg.theme_bw()
    + gg.geom_hline(yintercept=0, linetype="dashed", color="red")
    + gg.theme(strip_background=gg.element_rect(colour="black", fill="#fdfff4"))
    + gg.ggtitle("Compound grit")
)

output_file = pathlib.Path("figures/BR_NCP_PILOT_3_grit_compound.png")
grit_compare_gg.save(output_file, dpi=500, height=3, width=6.5)

grit_compare_gg
# Out:
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 6.5 x 3 in image.
# /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/BR_NCP_PILOT_3_grit_compound.png
# <ggplot: (453904053)>
