# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns 
import math
import statistics
import random

from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler

from collections import Counter

from pycytominer import normalize

# %% [markdown]
# # Functions

# %%
def load_data(path):
    """
    Loads the csv or csv.gz file into a pandas df, providing unique ID.
    """
    df = pd.read_csv(path)
    
    # Seperate data and metadata
    metadata_cols = [i for i in df.columns if 'Metadata' in i]
    metadata = df[metadata_cols]
    data_cols = [i for i in df.columns if i not in metadata_cols]
    
    # Remove exclude features from the data df
    data_cols = [x for x in data_cols if x.find('Costes')<0 if x.find('Manders')<0 if x.find('RWC')<0]
    data = df[data_cols]
    
    # Use metadata to create the index
    metadata_df = metadata.copy()
    data_df = data.copy()
    metadata_df['my_id'] = metadata['Metadata_line_source'] + '_' + metadata['Metadata_line_condition'] + '_' + \
        metadata['Metadata_line_ID'].astype(str) + '_' + metadata['Metadata_well_position']
    data_df['my_id'] = metadata_df['my_id']
    data_df.set_index('my_id', inplace=True)
    print('df shape: {}'.format(data_df.shape))
    
#     Remove the extraneous 'control' or 'deletion' for the isogenic perturbs, to keep naming consistency.
    new_idx = data_df.index.tolist()
    new_idx = [i.split('_')[0]+'_'+ i.split('_')[1]+'_'+ i.split('_')[3]+'_' +i.split('_')[4] \
               if 'genic' in i else i for i in new_idx]
    
    data_df.index = new_idx
    return metadata_df

# %%
def var_threshold_selection(data, threshold=0.01):
    selector = VarianceThreshold(threshold)
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

def corr_threshold_selection(df, threshold):
    corr = df.corr(method='spearman')
    columns = np.full((corr.shape[0],), True, dtype=bool)
    for i in range(corr.shape[0]):
        for j in range(i+1, corr.shape[0]):
            if corr.iloc[i,j] >= threshold:
                if columns[j]:
                    columns[j] = False
    selected_columns = df.columns[columns]
    selected_data = df[selected_columns]
    return selected_data

# %%
def plot_corr_matrix(df, return_corrs=True):
    corrs = df.corr(method='spearman')
    size = df.shape[1]
    fig, ax = plt.subplots(figsize=(size/4,size/5)) 
    sns.heatmap(corrs, cmap='coolwarm', ax=ax)
    
    vals = list(np.triu(corrs, k=1).flatten())
    vals = [i for i in vals if i != 0]
    mean_corr = sum(vals)/len(vals)
    stdev_corr = statistics.stdev(vals)
    print('Number of features: {}'.format(df.shape))
    print ('Mean corr: {}, Stdev corr: {}'.format(mean_corr, stdev_corr))
    if return_corrs:
        return corrs
    else: pass
    
def get_corr_between_compartments(metafeature_df):
    cells_df = metafeature_df.T[metafeature_df.T.index.str.startswith('Cells')]
    cyto_df = metafeature_df.T[metafeature_df.T.index.str.startswith('Cytoplasm')]
    nuc_df = metafeature_df.T[metafeature_df.T.index.str.startswith('Nuclei')]
    cells_vals = cells_df.values.flatten().tolist()
    nyto_vals = cyto_df.values.flatten().tolist()
    nuc_vals = nuc_df.values.flatten().tolist()
    
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(14, 4))
    ax1.scatter(cells_vals, cyto_vals)
    ax2.scatter(cells_vals, nuc_vals)
    ax3.scatter(cyto_vals, nuc_vals)
    print('R2 scores: {}, {}, {}'.format(r2_score(cells_vals, cyto_vals),
                                        r2_score(cells_vals, nuc_vals),
                                        r2_score(cyto_vals, nuc_vals)))

# %% [markdown]
# # Merge the data with metadata, and do plate normalization

# %%
from pathlib import Path
path = os.getcwd()
base_dir = str(Path(path).parent)

metadata = load_data(base_dir + '/1.run-workflows/profiles/NCP_STEM_1/BR_NCP_STEM_1/BR_NCP_STEM_1_normalized.csv.gz')
metadata = metadata[['Metadata_Well', 'my_id']]
# Out:
# df shape: (384, 4023)

# %%
data = pd.read_csv(base_dir + '/1.run-workflows/profiles/NCP_PROGENITORS_1/BR_NCP_PROGENITORS_1.csv.gz')
data_cols = [x for x in data.columns if x.find('Costes')<0 if x.find('Manders')<0 if x.find('RWC')<0]
data = data[data_cols]
data = normalize(data)
data = pd.merge(data, metadata, left_on='Metadata_Well', right_on='Metadata_Well')

data = data.drop(['Metadata_Plate', 'Metadata_Well'], axis=1)
data.set_index('my_id', inplace=True)

#     Remove the extraneous 'control' or 'deletion' for the isogenic perturbs, to keep naming consistency.
new_idx = data.index.tolist()
new_idx = [i.split('_')[0]+'_'+ i.split('_')[1]+'_'+ i.split('_')[3]+'_' +i.split('_')[4] \
           if 'genic' in i else i for i in new_idx]

data.index = new_idx

# %%
data
# Out:
#                        Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# human_control_1_A01                0.031558                 -0.083367
# human_control_1_A02               -0.054664                 -0.227870
# human_deletion_30_A03             -0.161378                 -0.030312
# human_deletion_30_A04             -0.141797                 -0.179424
# human_control_9_A05               -0.069913                  0.521924
# ...                                     ...                       ...
# human_control_13_P20               0.016831                  0.019864
# human_deletion_35_P21             -0.006812                  0.010482
# human_deletion_35_P22             -0.082822                  0.274600
# human_control_22_P23              -0.158956                  0.361959
# human_control_22_P24              -0.104509                 -0.160964
#
#                        Cells_AreaShape_Center_Y  Cells_AreaShape_Center_Z  \
# human_control_1_A01                   -0.376432                       0.0
# human_control_1_A02                   -0.113078                       0.0
# human_deletion_30_A03                  0.164265                       0.0
# human_deletion_30_A04                  0.070165                       0.0
# human_control_9_A05                   -1.602826                       0.0
# ...                                         ...                       ...
# human_control_13_P20                   0.241263                       0.0
# human_deletion_35_P21                 -0.314606                       0.0
# human_deletion_35_P22                 -0.218831                       0.0
# human_control_22_P23                   0.089901                       0.0
# human_control_22_P24                   0.341366                       0.0
#
#                        Cells_AreaShape_Compactness  \
# human_control_1_A01                       0.664552
# human_control_1_A02                      -0.182981
# human_deletion_30_A03                    -0.608366
# human_deletion_30_A04                    -0.555260
# human_control_9_A05                       1.036712
# ...                                            ...
# human_control_13_P20                     -0.263138
# human_deletion_35_P21                    -0.633877
# human_deletion_35_P22                    -0.706962
# human_control_22_P23                     -0.394386
# human_control_22_P24                     -0.165819
#
#                        Cells_AreaShape_Eccentricity  \
# human_control_1_A01                        0.391890
# human_control_1_A02                        0.057832
# human_deletion_30_A03                     -0.155454
# human_deletion_30_A04                     -0.092694
# human_control_9_A05                        0.399706
# ...                                             ...
# human_control_13_P20                       0.072305
# human_deletion_35_P21                      0.010154
# human_deletion_35_P22                     -0.052511
# human_control_22_P23                       0.093896
# human_control_22_P24                       0.157039
#
#                        Cells_AreaShape_EulerNumber  Cells_AreaShape_Extent  \
# human_control_1_A01                       0.378463               -0.780011
# human_control_1_A02                      -0.104090               -0.077548
# human_deletion_30_A03                    -0.328369                0.346617
# human_deletion_30_A04                    -0.218886                0.322870
# human_control_9_A05                      -0.082652               -0.907102
# ...                                            ...                     ...
# human_control_13_P20                     -1.013906                0.055551
# human_deletion_35_P21                    -0.197756                0.454381
# human_deletion_35_P22                     0.019505                0.503391
# human_control_22_P23                      0.132013                0.127585
# human_control_22_P24                      0.393510               -0.079611
#
#                        Cells_AreaShape_FormFactor  \
# human_control_1_A01                     -0.920009
# human_control_1_A02                     -0.245233
# human_deletion_30_A03                    0.120644
# human_deletion_30_A04                    0.137112
# human_control_9_A05                     -0.741057
# ...                                           ...
# human_control_13_P20                    -0.241643
# human_deletion_35_P21                    0.406647
# human_deletion_35_P22                    0.559702
# human_control_22_P23                     0.194439
# human_control_22_P24                    -0.078700
#
#                        Cells_AreaShape_MajorAxisLength  ...  \
# human_control_1_A01                           0.608907  ...
# human_control_1_A02                           0.116378  ...
# human_deletion_30_A03                        -0.384417  ...
# human_deletion_30_A04                        -0.304189  ...
# human_control_9_A05                           0.329826  ...
# ...                                                ...  ...
# human_control_13_P20                          0.235123  ...
# human_deletion_35_P21                        -0.441538  ...
# human_deletion_35_P22                        -0.512312  ...
# human_control_22_P23                         -0.309905  ...
# human_control_22_P24                         -0.061563  ...
#
#                        Nuclei_Texture_Variance_RNA_10_02  \
# human_control_1_A01                            -0.843344
# human_control_1_A02                            -1.078804
# human_deletion_30_A03                          -1.171375
# human_deletion_30_A04                          -0.909145
# human_control_9_A05                             0.740509
# ...                                                  ...
# human_control_13_P20                           -0.843951
# human_deletion_35_P21                          -1.181856
# human_deletion_35_P22                          -1.158347
# human_control_22_P23                           -0.607045
# human_control_22_P24                           -0.722846
#
#                        Nuclei_Texture_Variance_RNA_10_03  \
# human_control_1_A01                            -0.840968
# human_control_1_A02                            -1.086466
# human_deletion_30_A03                          -1.181463
# human_deletion_30_A04                          -0.913576
# human_control_9_A05                             0.735559
# ...                                                  ...
# human_control_13_P20                           -0.858732
# human_deletion_35_P21                          -1.168077
# human_deletion_35_P22                          -1.129080
# human_control_22_P23                           -0.593352
# human_control_22_P24                           -0.710867
#
#                        Nuclei_Texture_Variance_RNA_20_00  \
# human_control_1_A01                            -0.644202
# human_control_1_A02                            -0.908879
# human_deletion_30_A03                          -1.071824
# human_deletion_30_A04                          -0.828592
# human_control_9_A05                             0.881529
# ...                                                  ...
# human_control_13_P20                           -0.810453
# human_deletion_35_P21                          -1.387099
# human_deletion_35_P22                          -1.417583
# human_control_22_P23                           -0.672866
# human_control_22_P24                           -0.723234
#
#                        Nuclei_Texture_Variance_RNA_20_01  \
# human_control_1_A01                            -0.602125
# human_control_1_A02                            -0.929953
# human_deletion_30_A03                          -1.141703
# human_deletion_30_A04                          -0.856107
# human_control_9_A05                             1.041853
# ...                                                  ...
# human_control_13_P20                           -0.822422
# human_deletion_35_P21                          -1.434701
# human_deletion_35_P22                          -1.462290
# human_control_22_P23                           -0.687904
# human_control_22_P24                           -0.764467
#
#                        Nuclei_Texture_Variance_RNA_20_02  \
# human_control_1_A01                            -0.644084
# human_control_1_A02                            -0.914194
# human_deletion_30_A03                          -1.073357
# human_deletion_30_A04                          -0.824114
# human_control_9_A05                             0.877049
# ...                                                  ...
# human_control_13_P20                           -0.810289
# human_deletion_35_P21                          -1.396777
# human_deletion_35_P22                          -1.423246
# human_control_22_P23                           -0.667905
# human_control_22_P24                           -0.728877
#
#                        Nuclei_Texture_Variance_RNA_20_03  \
# human_control_1_A01                            -0.607883
# human_control_1_A02                            -0.941841
# human_deletion_30_A03                          -1.139353
# human_deletion_30_A04                          -0.869313
# human_control_9_A05                             1.149829
# ...                                                  ...
# human_control_13_P20                           -0.833615
# human_deletion_35_P21                          -1.461724
# human_deletion_35_P22                          -1.470335
# human_control_22_P23                           -0.695881
# human_control_22_P24                           -0.770111
#
#                        Nuclei_Texture_Variance_RNA_5_00  \
# human_control_1_A01                           -0.849810
# human_control_1_A02                           -1.085625
# human_deletion_30_A03                         -1.183812
# human_deletion_30_A04                         -0.914348
# human_control_9_A05                            0.785405
# ...                                                 ...
# human_control_13_P20                          -0.842753
# human_deletion_35_P21                         -1.192992
# human_deletion_35_P22                         -1.180942
# human_control_22_P23                          -0.616162
# human_control_22_P24                          -0.737506
#
#                        Nuclei_Texture_Variance_RNA_5_01  \
# human_control_1_A01                           -0.848555
# human_control_1_A02                           -1.082379
# human_deletion_30_A03                         -1.177876
# human_deletion_30_A04                         -0.911870
# human_control_9_A05                            0.765654
# ...                                                 ...
# human_control_13_P20                          -0.844238
# human_deletion_35_P21                         -1.189867
# human_deletion_35_P22                         -1.176140
# human_control_22_P23                          -0.615263
# human_control_22_P24                          -0.735103
#
#                        Nuclei_Texture_Variance_RNA_5_02  \
# human_control_1_A01                           -0.848786
# human_control_1_A02                           -1.083933
# human_deletion_30_A03                         -1.182150
# human_deletion_30_A04                         -0.914511
# human_control_9_A05                            0.787896
# ...                                                 ...
# human_control_13_P20                          -0.841745
# human_deletion_35_P21                         -1.191645
# human_deletion_35_P22                         -1.178161
# human_control_22_P23                          -0.614708
# human_control_22_P24                          -0.736419
#
#                        Nuclei_Texture_Variance_RNA_5_03
# human_control_1_A01                           -0.847515
# human_control_1_A02                           -1.078993
# human_deletion_30_A03                         -1.177294
# human_deletion_30_A04                         -0.907822
# human_control_9_A05                            0.762142
# ...                                                 ...
# human_control_13_P20                          -0.841695
# human_deletion_35_P21                         -1.190141
# human_deletion_35_P22                         -1.173465
# human_control_22_P23                          -0.611955
# human_control_22_P24                          -0.731574
#
# [380 rows x 4023 columns]

# %%
# # Exact same as cytominer normalize
# scaler = StandardScaler()
# scaler.fit(data)
# data_df = pd.DataFrame(scaler.transform(data), index=data.index, columns=data.columns)
# data_df

# %%
with pd.option_context("display.max_rows", 555):
#     display(data.sort_values(by='Cells_AreaShape_Area'))
    display(data)
# Out:
#                           Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# human_control_1_A01                   0.031558                 -0.083367
# human_control_1_A02                  -0.054664                 -0.227870
# human_deletion_30_A03                -0.161378                 -0.030312
# human_deletion_30_A04                -0.141797                 -0.179424
# human_control_9_A05                  -0.069913                  0.521924
# human_control_9_A06                   0.006089                  0.412618
# isogenic_deletion_26_A07             -0.091128                  0.879262
# isogenic_deletion_26_A08             -0.067618                  0.338606
# human_control_4_A09                  -0.126587                  0.185204
# human_control_4_A10                  -0.173647                 -0.182555
# human_deletion_34_A11                -0.256708                  0.046429
# human_deletion_34_A12                -0.269047                  0.059444
# human_control_15_A13                 -0.165228                 -0.248270
# human_control_15_A14                 -0.149038                 -0.237869
# human_deletion_36_A15                -0.122441                  0.443635
# human_deletion_36_A16                -0.220156                  0.373123
# human_control_2_A17                  -0.071255                 -0.211674
# human_control_2_A18                  -0.119253                 -0.136874
# human_control_16_A19                  0.308559                  0.087669
# human_control_16_A20                 -0.204883                 -0.063049
# human_control_20_A21                 -0.083813                 -0.372175
# human_control_20_A22                 -0.148821                 -0.131370
# human_control_12_A23                 -0.047733                  0.103950
# human_control_12_A24                 -0.069881                 -0.125915
# human_control_1_B01                  -0.071026                 -0.189604
# human_control_1_B02                  -0.023970                  0.038922
# human_deletion_30_B03                -0.135318                  0.009829
# human_deletion_30_B04                -0.078035                 -0.184415
# human_control_9_B05                   0.033015                  1.580772
# human_control_9_B06                  -0.025882                  0.747002
# isogenic_deletion_26_B07             -0.098616                  0.928452
# isogenic_deletion_26_B08             -0.131212                  0.269370
# human_control_4_B09                  -0.159990                  0.022034
# human_control_4_B10                  -0.195261                  0.015821
# human_deletion_34_B11                -0.257031                 -0.083712
# human_deletion_34_B12                -0.270639                 -0.061834
# human_control_15_B13                 -0.130381                 -0.353414
# human_control_15_B14                 -0.108111                 -0.705237
# human_deletion_36_B15                -0.191478                  0.155736
# human_deletion_36_B16                -0.175673                  0.738910
# human_control_2_B17                  -0.076766                  0.073870
# human_control_2_B18                  -0.095818                 -0.123857
# human_control_16_B19                 -0.209711                  0.082250
# human_control_16_B20                 -0.209826                 -0.043188
# human_control_20_B21                 -0.191709                 -0.149335
# human_control_20_B22                 -0.159880                  0.198050
# human_control_12_B23                 -0.074673                 -0.209072
# human_control_12_B24                 -0.074216                 -0.094669
# human_control_17_C01                 -0.093396                 -0.267768
# human_control_17_C02                 -0.132920                 -0.018636
# human_deletion_39_C03                -0.144286                  0.085331
# human_deletion_39_C04                -0.169973                 -0.019139
# human_deletion_37_C05                -0.177283                  0.073516
# human_deletion_37_C06                -0.204479                  0.106264
# human_deletion_42_C07                -0.161561                 -0.119200
# human_deletion_42_C08                -0.200914                 -0.157297
# human_control_7_C09                  -0.125422                  0.124950
# human_control_7_C10                  -0.165746                  0.304658
# human_deletion_29_C11                -0.122945                  0.298492
# human_deletion_29_C12                -0.147205                  0.102299
# human_control_11_C13                 -0.073479                 -0.029211
# human_control_11_C14                 -0.136870                 -0.321028
# human_deletion_38_C15                -0.268734                 -0.111331
# human_deletion_38_C16                -0.276429                  0.036410
# human_deletion_43_C17                -0.136049                  0.056426
# human_deletion_43_C18                -0.151859                 -0.314713
# human_control_18_C19                 -0.169306                 -0.166138
# human_control_18_C20                 -0.189982                 -0.106922
# human_control_6_C21                   0.286662                 -2.602099
# human_control_6_C22                  -0.245122                 -1.361178
# human_deletion_29_C23                -0.138215                 -0.080609
# human_deletion_29_C24                -0.171409                 -0.024889
# human_control_17_D01                 -0.071223                 -0.127719
# human_control_17_D02                 -0.081190                 -0.508110
# human_deletion_39_D03                -0.149127                  0.135356
# human_deletion_39_D04                -0.179312                 -0.003554
# human_deletion_37_D05                -0.192425                 -0.124640
# human_deletion_37_D06                -0.185175                 -0.296114
# human_deletion_42_D07                -0.184503                 -0.316699
# human_deletion_42_D08                -0.191438                 -0.327563
# human_control_7_D09                  -0.139582                 -0.129981
# human_control_7_D10                  -0.119081                  0.453390
# human_deletion_29_D11                -0.152674                  0.084195
# human_deletion_29_D12                -0.105505                  0.348211
# human_control_11_D13                 -0.130107                 -0.250561
# human_control_11_D14                 -0.114713                 -0.352328
# human_deletion_38_D15                -0.279187                 -0.104548
# human_deletion_38_D16                -0.276275                 -0.008575
# human_deletion_43_D17                 0.099433                  0.336505
# human_deletion_43_D18                -0.172365                 -0.074494
# human_control_18_D19                 -0.178578                  0.011149
# human_control_18_D20                 -0.177456                 -0.267366
# human_control_6_D21                  -0.001830                 -1.365316
# human_control_6_D22                  -0.251220                  2.731052
# human_deletion_29_D23                -0.156078                  0.031837
# human_deletion_29_D24                -0.176030                  0.015709
# human_deletion_27_E01                -0.146009                 -0.193853
# human_deletion_27_E02                -0.176520                 -0.048832
# human_deletion_41_E03                 0.063200                  1.674216
# human_deletion_41_E04                -0.019021                 -0.487748
# human_deletion_32_E05                -0.215115                 -0.021258
# human_deletion_32_E06                -0.213301                 -0.006165
# human_deletion_46_E07                -0.025960                  1.603458
# human_deletion_46_E08                -0.019104                  0.890741
# human_control_1_E09                  -0.046063                 -0.179383
# human_control_1_E10                  -0.062556                 -0.146574
# human_deletion_33_E11                -0.274847                 -0.406624
# human_deletion_33_E12                -0.451226                -10.682120
# human_control_14_E13                 -0.161503                 -0.312478
# human_control_14_E14                 -0.175299                 -0.111446
# human_control_9_E15                   0.001631                  0.093760
# human_control_9_E16                  -0.045503                  0.537539
# isogenic_control_23_E17              -0.186054                 -0.113281
# isogenic_control_23_E18              -0.160224                 -0.324776
# human_control_22_E19                 -0.140025                 -0.168735
# human_control_22_E20                 -0.153833                 -0.135936
# human_control_3_E21                  -0.148543                  0.119351
# human_control_3_E22                  -0.181921                 -0.243409
# human_deletion_28_E23                -0.141523                 -0.060537
# human_deletion_28_E24                -0.193464                  0.034307
# human_deletion_27_F01                -0.131756                 -0.578655
# human_deletion_27_F02                -0.151402                 -0.148416
# human_deletion_41_F03                 0.082960                  1.830668
# human_deletion_41_F04                 0.270232                  0.446195
# human_deletion_32_F05                -0.212110                 -0.034652
# human_deletion_32_F06                -0.187524                 -0.105582
# human_deletion_46_F07                -0.053180                  0.394608
# human_deletion_46_F08                -0.057596                  0.041286
# human_control_1_F09                  -0.046146                 -0.091444
# human_control_1_F10                  -0.029874                 -0.100818
# human_control_14_F13                 -0.170723                 -0.081281
# human_control_14_F14                 -0.179653                 -0.304456
# human_control_9_F15                  -0.019648                  0.432153
# human_control_9_F16                   0.012848                  0.890162
# isogenic_control_23_F17              -0.203654                  0.190867
# isogenic_control_23_F18               0.005084                  1.733069
# human_control_22_F19                 -0.130920                  0.066368
# human_control_22_F20                 -0.172853                 -0.390641
# human_control_3_F21                  -0.194954                 -0.224942
# human_control_3_F22                  -0.184839                 -0.172478
# human_deletion_28_F23                -0.171092                 -0.267824
# human_deletion_28_F24                -0.161659                  0.227643
# human_control_5_G01                  -0.246016                  1.845512
# human_control_5_G02                  -0.256765                  0.903783
# human_deletion_35_G03                -0.134545                 -0.101668
# human_deletion_35_G04                -0.134935                 -0.058917
# human_control_13_G05                  0.031238                 -0.105322
# human_control_13_G06                  0.029550                 -0.108085
# human_control_19_G07                 -0.151867                 -0.000524
# human_control_19_G08                 -0.166189                 -0.086790
# isogenic_control_24_G09              -0.060286                 -0.142878
# isogenic_control_24_G10              -0.074991                  0.111059
# human_control_17_G11                 -0.087922                  0.140777
# human_control_17_G12                 -0.104887                  0.392374
# human_control_21_G13                  0.014375                 -0.870695
# human_control_21_G14                  0.062640                  0.397102
# human_deletion_28_G15                -0.173921                 -0.162588
# human_deletion_28_G16                -0.179798                 -0.041503
# human_deletion_31_G17                -0.071424                  0.260999
# human_deletion_31_G18                -0.023813                 -0.027993
# human_control_10_G19                  0.073596                 -0.172830
# human_control_10_G20                 -0.029096                  0.137278
# human_deletion_45_G21                -0.219940                 -0.087578
# human_deletion_45_G22                -0.223266                  0.086341
# human_control_11_G23                 -0.123020                  0.182307
# human_control_11_G24                 -0.053840                  0.102030
# human_control_5_H01                  -0.223151                  0.567717
# human_control_5_H02                  -0.242957                  0.812115
# human_deletion_35_H03                -0.198192                 -0.206395
# human_deletion_35_H04                -0.211296                 -0.002738
# human_control_13_H05                  0.001091                  0.017150
# human_control_13_H06                  0.023200                  0.070360
# human_control_19_H07                 -0.173224                 -0.089263
# human_control_19_H08                 -0.135265                 -0.158152
# isogenic_control_24_H09              -0.101466                 -0.071959
# isogenic_control_24_H10              -0.069667                 -0.333703
# human_control_17_H11                 -0.077657                  0.155854
# human_control_17_H12                 -0.113913                  0.128623
# human_control_21_H13                  0.078144                 -0.884811
# human_control_21_H14                  0.069134                 -0.839316
# human_deletion_28_H15                -0.192568                 -0.207706
# human_deletion_28_H16                -0.208972                 -0.037709
# human_deletion_31_H17                -0.073078                  0.422143
# human_deletion_31_H18                -0.061469                  0.239451
# human_control_10_H19                 -0.006357                 -0.472482
# human_control_10_H20                 -0.017614                  0.031885
# human_deletion_45_H21                -0.204603                  0.119693
# human_deletion_45_H22                -0.216519                  0.204471
# human_control_11_H23                 -0.142692                 -0.098436
# human_control_11_H24                 -0.082776                  0.206930
# isogenic_control_24_I01              -0.045727                 -1.090485
# isogenic_control_24_I02              -0.045548                  0.354698
# human_deletion_38_I03                -0.273805                 -0.023287
# human_deletion_38_I04                -0.277365                 -0.112712
# human_deletion_44_I05                -0.216526                 -0.133602
# human_deletion_44_I06                -0.234905                  0.015811
# human_deletion_47_I07                -0.192277                  0.034409
# human_deletion_47_I08                -0.205886                  0.012284
# human_control_20_I09                 -0.134696                  0.082466
# human_control_20_I10                 -0.170156                  0.063085
# human_control_12_I11                  2.946440                  0.390389
# human_control_12_I12                  3.928570                 -0.383328
# human_deletion_47_I13                -0.199720                  0.044638
# human_deletion_47_I14                -0.201871                 -0.146693
# human_control_5_I15                  -0.204445                  1.277683
# human_control_5_I16                  -0.187698                  0.517170
# human_deletion_40_I17                -0.033219                 -0.036372
# human_deletion_40_I18                -0.056286                 -0.061732
# human_deletion_27_I19                -0.169156                 -0.172253
# human_deletion_27_I20                -0.178651                 -0.005233
# human_deletion_42_I21                -0.191927                 -0.053463
# human_deletion_42_I22                -0.188175                  0.042155
# human_control_19_I23                 -0.148000                 -0.358098
# human_control_19_I24                 -0.151768                 -0.104959
# isogenic_control_24_J01              -0.053717                 -0.504430
# isogenic_control_24_J02              -0.044341                 -0.214042
# human_deletion_38_J03                -0.276052                 -0.035442
# human_deletion_38_J04                -0.273545                 -0.193333
# human_deletion_44_J05                -0.225593                 -0.152166
# human_deletion_44_J06                -0.230387                 -0.279036
# human_deletion_47_J07                -0.206635                 -0.145106
# human_deletion_47_J08                -0.194556                 -0.185873
# human_control_20_J09                 -0.152818                 -0.117683
# human_control_20_J10                 -0.155848                 -0.134083
# human_control_12_J11                  4.126824                 -0.916753
# human_control_12_J12                  1.383598                 -0.186015
# human_deletion_47_J13                -0.201284                 -0.069683
# human_deletion_47_J14                -0.197316                  0.022674
# human_control_5_J15                  -0.214442                 -1.787632
# human_control_5_J16                  -0.185530                  2.822841
# human_deletion_40_J17                -0.049614                 -0.104551
# human_deletion_40_J18                -0.039990                 -0.217524
# human_deletion_27_J19                -0.186357                 -0.066214
# human_deletion_27_J20                -0.187682                 -0.269854
# human_deletion_42_J21                -0.190518                 -0.120571
# human_deletion_42_J22                -0.184375                 -0.212728
# human_control_19_J23                 -0.164093                 -0.278784
# human_control_19_J24                 -0.155205                 -0.155617
# human_control_6_K01                  -0.273068                  7.690242
# human_control_6_K02                  -0.106700                 -0.291020
# human_deletion_40_K03                -0.009199                 -0.103789
# human_deletion_40_K04                -0.018599                 -0.017861
# human_deletion_41_K05                 0.151179                  2.599904
# human_deletion_41_K06                 0.050301                  0.019303
# human_control_2_K07                  -0.035450                 -0.011782
# human_control_2_K08                  -0.056853                  0.058038
# isogenic_deletion_26_K09             -0.092774                  1.674338
# isogenic_deletion_26_K10             -0.106744                  0.069872
# human_deletion_48_K11                -0.188896                  0.065618
# human_deletion_48_K12                -0.189923                  0.055078
# human_deletion_39_K13                -0.146232                 -0.155649
# human_deletion_39_K14                -0.172379                 -0.092086
# human_deletion_48_K15                -0.198580                 -0.145536
# human_deletion_48_K16                -0.203434                 -0.047463
# human_deletion_30_K17                -0.087199                 -0.083361
# human_deletion_30_K18                -0.101020                 -0.051016
# human_control_8_K19                  -0.060024                 -0.564811
# human_control_8_K20                  -0.059073                 -0.425103
# human_deletion_46_K21                -0.009174                  0.750771
# human_deletion_46_K22                 0.003120                  0.943556
# human_deletion_32_K23                -0.209944                 -0.058799
# human_deletion_32_K24                -0.208215                  0.172153
# human_control_6_L01                  -0.028479                 -1.488452
# human_control_6_L02                  -0.202350                 -0.803419
# human_deletion_40_L03                -0.021204                 -0.215075
# human_deletion_40_L04                 0.000922                 -0.126138
# human_deletion_41_L05                 0.102911                 -0.095294
# human_deletion_41_L06                 0.026853                  0.288624
# human_control_2_L07                  -0.042514                  0.162178
# human_control_2_L08                  -0.014795                 -0.113287
# isogenic_deletion_26_L09             -0.067574                 -1.336499
# isogenic_deletion_26_L10             -0.087081                  0.037497
# human_deletion_48_L11                -0.195595                 -0.097679
# human_deletion_48_L12                -0.199811                 -0.030735
# human_deletion_39_L13                -0.167776                 -0.143055
# human_deletion_39_L14                -0.157227                 -0.262540
# human_deletion_48_L15                -0.199055                 -0.121667
# human_deletion_48_L16                -0.193691                 -0.202043
# human_deletion_30_L17                -0.117082                  0.141248
# human_deletion_30_L18                -0.128638                 -0.374996
# human_control_8_L19                  -0.062197                  0.183827
# human_control_8_L20                  -0.039155                  0.155472
# human_deletion_46_L21                -0.077090                  0.966982
# human_deletion_46_L22                -0.041967                  0.784383
# human_deletion_32_L23                -0.220815                  0.073028
# human_deletion_32_L24                -0.182738                  0.050984
# human_control_14_M01                 -0.178640                 -0.142902
# human_control_14_M02                 -0.159144                 -0.268579
# human_deletion_36_M03                -0.235404                  0.308149
# human_deletion_36_M04                -0.237476                  0.234300
# human_deletion_43_M05                -0.035709                  0.026328
# human_deletion_43_M06                 0.008043                  0.224289
# human_control_16_M07                  0.503426                 -0.174585
# human_control_16_M08                 13.713626                 -1.074335
# human_deletion_45_M09                -0.221543                  0.025479
# human_deletion_45_M10                -0.216831                 -0.167757
# human_control_4_M11                  -0.164995                 -0.024412
# human_control_4_M12                  -0.144852                  0.092436
# isogenic_deletion_25_M13             -0.077857                 -0.274053
# isogenic_deletion_25_M14             -0.057499                 -0.894578
# human_deletion_34_M15                -0.272853                 -0.038624
# human_deletion_34_M16                -0.272163                  0.069062
# human_deletion_44_M17                -0.221948                 -0.148655
# human_deletion_44_M18                -0.214523                 -0.355690
# human_control_15_M19                 -0.129434                 -0.038430
# human_control_15_M20                 -0.122490                  0.022424
# human_deletion_37_M21                -0.205499                  0.041981
# human_deletion_37_M22                -0.215869                  0.069035
# human_control_7_M23                  -0.128121                 -0.042746
# human_control_7_M24                   0.025652                  0.197453
# human_control_14_N01                 -0.169794                 -0.231680
# human_control_14_N02                 -0.167665                 -0.301251
# human_deletion_36_N03                -0.222416                  0.174950
# human_deletion_36_N04                -0.243341                 -0.058259
# human_deletion_43_N05                 0.000907                  0.057029
# human_deletion_43_N06                -0.010129                  0.110590
# human_control_16_N07                 10.407086                 -0.329313
# human_control_16_N08                  5.484518                 -0.462759
# human_deletion_45_N09                -0.216478                  0.146775
# human_deletion_45_N10                -0.211126                  0.072814
# human_control_4_N11                  -0.140380                 -0.018279
# human_control_4_N12                  -0.152479                 -0.094874
# isogenic_deletion_25_N13             -0.064683                  0.511803
# isogenic_deletion_25_N14             -0.034613                  0.023315
# human_deletion_34_N15                -0.264227                 -0.019643
# human_deletion_34_N16                -0.261005                  0.054992
# human_deletion_44_N17                -0.225731                  0.011583
# human_deletion_44_N18                -0.218351                 -0.051151
# human_control_15_N19                 -0.134126                 -0.143217
# human_control_15_N20                 -0.120365                 -0.194446
# human_deletion_37_N21                -0.190258                  0.030457
# human_deletion_37_N22                -0.178602                 -0.128446
# human_control_7_N23                  -0.192672                 -0.370293
# human_control_7_N24                   0.026188                  0.257371
# human_control_10_O01                  0.125020                 -0.451989
# human_control_10_O02                  0.101182                  0.381518
# isogenic_deletion_25_O03             -0.094606                 -0.371605
# isogenic_deletion_25_O04             -0.068864                  0.011138
# human_control_8_O05                   0.018189                 -0.485689
# human_control_8_O06                   0.022840                  0.162326
# human_deletion_31_O07                -0.012956                  0.383756
# human_deletion_31_O08                 0.006337                  0.226690
# human_control_18_O09                 -0.138451                 -0.108547
# human_control_18_O10                 -0.148673                  0.059023
# human_control_21_O11                  0.218784                  0.428311
# human_control_21_O12                  0.214243                  0.216737
# human_control_3_O13                  -0.125681                 -0.156711
# human_control_3_O14                  -0.147135                 -0.018435
# isogenic_control_23_O15              -0.128680                 -0.099623
# isogenic_control_23_O16              -0.162290                 -0.062132
# human_deletion_33_O17                -0.503276                  4.388608
# human_control_13_O19                 -0.016801                 -0.048569
# human_control_13_O20                 -0.018901                  0.017917
# human_deletion_35_O21                -0.074320                  0.159409
# human_deletion_35_O22                 0.025434                  0.490587
# human_control_22_O23                 -0.134783                 -0.002003
# human_control_22_O24                 -0.141145                  0.517196
# human_control_10_P01                  0.124413                 -0.468664
# human_control_10_P02                  0.084166                 -0.554347
# isogenic_deletion_25_P03             -0.084372                  0.423032
# isogenic_deletion_25_P04             -0.066364                  0.307973
# human_control_8_P05                  -0.002489                  0.603971
# human_control_8_P06                   0.030429                  0.092034
# human_deletion_31_P07                 0.022535                  0.474020
# human_deletion_31_P08                -0.025908                  0.105860
# human_control_18_P09                 -0.133274                  0.123947
# human_control_18_P10                 -0.132216                  0.116077
# human_control_21_P11                  0.401567                  1.149474
# human_control_21_P12                  0.452629                  1.313141
# human_control_3_P13                  -0.128525                 -0.125933
# human_control_3_P14                  -0.112674                  0.059101
# isogenic_control_23_P15              -0.175143                  0.128369
# isogenic_control_23_P16              -0.166847                  0.283020
# human_deletion_33_P17                 0.858207                 -9.473018
# human_control_13_P19                 -0.014410                 -0.040278
# human_control_13_P20                  0.016831                  0.019864
# human_deletion_35_P21                -0.006812                  0.010482
# human_deletion_35_P22                -0.082822                  0.274600
# human_control_22_P23                 -0.158956                  0.361959
# human_control_22_P24                 -0.104509                 -0.160964
#
#                           Cells_AreaShape_Center_Y  Cells_AreaShape_Center_Z  \
# human_control_1_A01                      -0.376432                       0.0
# human_control_1_A02                      -0.113078                       0.0
# human_deletion_30_A03                     0.164265                       0.0
# human_deletion_30_A04                     0.070165                       0.0
# human_control_9_A05                      -1.602826                       0.0
# human_control_9_A06                       0.225723                       0.0
# isogenic_deletion_26_A07                  0.263472                       0.0
# isogenic_deletion_26_A08                 -0.834704                       0.0
# human_control_4_A09                       0.585579                       0.0
# human_control_4_A10                      -0.124774                       0.0
# human_deletion_34_A11                     0.123525                       0.0
# human_deletion_34_A12                     0.015800                       0.0
# human_control_15_A13                     -0.169413                       0.0
# human_control_15_A14                     -0.305033                       0.0
# human_deletion_36_A15                    -0.363477                       0.0
# human_deletion_36_A16                    -0.341389                       0.0
# human_control_2_A17                       0.425354                       0.0
# human_control_2_A18                       0.409033                       0.0
# human_control_16_A19                     -1.821262                       0.0
# human_control_16_A20                      0.081462                       0.0
# human_control_20_A21                     -0.737803                       0.0
# human_control_20_A22                     -0.431908                       0.0
# human_control_12_A23                      0.028094                       0.0
# human_control_12_A24                      0.304596                       0.0
# human_control_1_B01                       0.039244                       0.0
# human_control_1_B02                      -0.071703                       0.0
# human_deletion_30_B03                     0.017441                       0.0
# human_deletion_30_B04                     0.014647                       0.0
# human_control_9_B05                      -1.166660                       0.0
# human_control_9_B06                      -1.794729                       0.0
# isogenic_deletion_26_B07                  0.029884                       0.0
# isogenic_deletion_26_B08                 -0.323951                       0.0
# human_control_4_B09                       0.392293                       0.0
# human_control_4_B10                       0.083189                       0.0
# human_deletion_34_B11                    -0.039241                       0.0
# human_deletion_34_B12                     0.028896                       0.0
# human_control_15_B13                     -0.244338                       0.0
# human_control_15_B14                      0.131778                       0.0
# human_deletion_36_B15                    -0.889476                       0.0
# human_deletion_36_B16                     0.560717                       0.0
# human_control_2_B17                       0.058110                       0.0
# human_control_2_B18                       0.387272                       0.0
# human_control_16_B19                      0.238173                       0.0
# human_control_16_B20                      0.217803                       0.0
# human_control_20_B21                     -0.376896                       0.0
# human_control_20_B22                      0.904608                       0.0
# human_control_12_B23                     -0.051088                       0.0
# human_control_12_B24                      0.377325                       0.0
# human_control_17_C01                     -0.889818                       0.0
# human_control_17_C02                      0.337766                       0.0
# human_deletion_39_C03                    -0.160149                       0.0
# human_deletion_39_C04                     0.042447                       0.0
# human_deletion_37_C05                     0.167782                       0.0
# human_deletion_37_C06                     0.182610                       0.0
# human_deletion_42_C07                     0.264930                       0.0
# human_deletion_42_C08                     0.424033                       0.0
# human_control_7_C09                      -0.629463                       0.0
# human_control_7_C10                      -0.073568                       0.0
# human_deletion_29_C11                     0.168597                       0.0
# human_deletion_29_C12                     0.022110                       0.0
# human_control_11_C13                     -0.497000                       0.0
# human_control_11_C14                     -0.085697                       0.0
# human_deletion_38_C15                     0.084040                       0.0
# human_deletion_38_C16                     0.090187                       0.0
# human_deletion_43_C17                     0.433577                       0.0
# human_deletion_43_C18                     0.174772                       0.0
# human_control_18_C19                      0.409477                       0.0
# human_control_18_C20                      0.145428                       0.0
# human_control_6_C21                       2.235017                       0.0
# human_control_6_C22                       0.451633                       0.0
# human_deletion_29_C23                     0.101956                       0.0
# human_deletion_29_C24                     0.127599                       0.0
# human_control_17_D01                      0.438372                       0.0
# human_control_17_D02                      0.122462                       0.0
# human_deletion_39_D03                     0.096332                       0.0
# human_deletion_39_D04                    -0.279271                       0.0
# human_deletion_37_D05                    -0.088691                       0.0
# human_deletion_37_D06                     0.086738                       0.0
# human_deletion_42_D07                     0.297805                       0.0
# human_deletion_42_D08                     0.206439                       0.0
# human_control_7_D09                      -0.003677                       0.0
# human_control_7_D10                      -0.657861                       0.0
# human_deletion_29_D11                    -0.251508                       0.0
# human_deletion_29_D12                     0.125055                       0.0
# human_control_11_D13                      0.626544                       0.0
# human_control_11_D14                      0.100331                       0.0
# human_deletion_38_D15                     0.086319                       0.0
# human_deletion_38_D16                     0.194667                       0.0
# human_deletion_43_D17                     0.049348                       0.0
# human_deletion_43_D18                     0.271641                       0.0
# human_control_18_D19                      0.105452                       0.0
# human_control_18_D20                      0.328919                       0.0
# human_control_6_D21                      -0.892765                       0.0
# human_control_6_D22                      -1.017164                       0.0
# human_deletion_29_D23                     0.081997                       0.0
# human_deletion_29_D24                     0.396874                       0.0
# human_deletion_27_E01                     0.084217                       0.0
# human_deletion_27_E02                     0.385626                       0.0
# human_deletion_41_E03                    -2.487576                       0.0
# human_deletion_41_E04                    -0.389714                       0.0
# human_deletion_32_E05                     0.099919                       0.0
# human_deletion_32_E06                     0.178018                       0.0
# human_deletion_46_E07                    -1.307263                       0.0
# human_deletion_46_E08                    -0.885328                       0.0
# human_control_1_E09                      -0.235877                       0.0
# human_control_1_E10                      -0.049102                       0.0
# human_deletion_33_E11                     0.489344                       0.0
# human_deletion_33_E12                    -4.741906                       0.0
# human_control_14_E13                     -0.178891                       0.0
# human_control_14_E14                     -0.191145                       0.0
# human_control_9_E15                       0.561046                       0.0
# human_control_9_E16                       0.381383                       0.0
# isogenic_control_23_E17                  -0.532842                       0.0
# isogenic_control_23_E18                  -0.355744                       0.0
# human_control_22_E19                     -0.066207                       0.0
# human_control_22_E20                      0.095565                       0.0
# human_control_3_E21                       0.041475                       0.0
# human_control_3_E22                       0.176199                       0.0
# human_deletion_28_E23                     0.289682                       0.0
# human_deletion_28_E24                     0.299644                       0.0
# human_deletion_27_F01                    -0.542064                       0.0
# human_deletion_27_F02                     0.038447                       0.0
# human_deletion_41_F03                    -0.976003                       0.0
# human_deletion_41_F04                     0.288721                       0.0
# human_deletion_32_F05                     0.116795                       0.0
# human_deletion_32_F06                     0.155722                       0.0
# human_deletion_46_F07                    -0.820099                       0.0
# human_deletion_46_F08                    -1.293119                       0.0
# human_control_1_F09                      -0.158265                       0.0
# human_control_1_F10                      -0.342302                       0.0
# human_control_14_F13                     -0.428956                       0.0
# human_control_14_F14                     -0.932171                       0.0
# human_control_9_F15                      -0.004708                       0.0
# human_control_9_F16                       0.162981                       0.0
# isogenic_control_23_F17                  -0.398699                       0.0
# isogenic_control_23_F18                  -0.832083                       0.0
# human_control_22_F19                      0.426942                       0.0
# human_control_22_F20                     -0.131965                       0.0
# human_control_3_F21                       0.190159                       0.0
# human_control_3_F22                       0.526988                       0.0
# human_deletion_28_F23                     0.156745                       0.0
# human_deletion_28_F24                     0.029365                       0.0
# human_control_5_G01                       1.055517                       0.0
# human_control_5_G02                      -1.210668                       0.0
# human_deletion_35_G03                    -0.016672                       0.0
# human_deletion_35_G04                     0.536351                       0.0
# human_control_13_G05                      0.287305                       0.0
# human_control_13_G06                      0.067327                       0.0
# human_control_19_G07                      0.277032                       0.0
# human_control_19_G08                      0.264952                       0.0
# isogenic_control_24_G09                   0.455621                       0.0
# isogenic_control_24_G10                  -0.019504                       0.0
# human_control_17_G11                      0.256885                       0.0
# human_control_17_G12                      0.051759                       0.0
# human_control_21_G13                     -2.026673                       0.0
# human_control_21_G14                      0.052821                       0.0
# human_deletion_28_G15                     0.204779                       0.0
# human_deletion_28_G16                     0.626335                       0.0
# human_deletion_31_G17                     0.382729                       0.0
# human_deletion_31_G18                     0.662496                       0.0
# human_control_10_G19                      0.485534                       0.0
# human_control_10_G20                     -0.098768                       0.0
# human_deletion_45_G21                     0.113958                       0.0
# human_deletion_45_G22                     0.293518                       0.0
# human_control_11_G23                      0.490189                       0.0
# human_control_11_G24                      0.242515                       0.0
# human_control_5_H01                      -2.287912                       0.0
# human_control_5_H02                       0.053339                       0.0
# human_deletion_35_H03                     0.162086                       0.0
# human_deletion_35_H04                    -0.064086                       0.0
# human_control_13_H05                      0.285055                       0.0
# human_control_13_H06                      0.085481                       0.0
# human_control_19_H07                      0.217491                       0.0
# human_control_19_H08                      0.008446                       0.0
# isogenic_control_24_H09                   0.140238                       0.0
# isogenic_control_24_H10                   0.134784                       0.0
# human_control_17_H11                     -0.071435                       0.0
# human_control_17_H12                      0.423805                       0.0
# human_control_21_H13                     -0.001619                       0.0
# human_control_21_H14                     -0.666021                       0.0
# human_deletion_28_H15                     0.465988                       0.0
# human_deletion_28_H16                     0.363861                       0.0
# human_deletion_31_H17                     0.294056                       0.0
# human_deletion_31_H18                     0.197113                       0.0
# human_control_10_H19                      0.684818                       0.0
# human_control_10_H20                      0.616167                       0.0
# human_deletion_45_H21                     0.297709                       0.0
# human_deletion_45_H22                     0.323366                       0.0
# human_control_11_H23                      0.327389                       0.0
# human_control_11_H24                      0.544265                       0.0
# isogenic_control_24_I01                  -0.909080                       0.0
# isogenic_control_24_I02                  -0.281736                       0.0
# human_deletion_38_I03                     0.107893                       0.0
# human_deletion_38_I04                     0.128133                       0.0
# human_deletion_44_I05                     0.191302                       0.0
# human_deletion_44_I06                     0.163873                       0.0
# human_deletion_47_I07                     0.132448                       0.0
# human_deletion_47_I08                     0.095523                       0.0
# human_control_20_I09                     -0.139571                       0.0
# human_control_20_I10                     -0.011339                       0.0
# human_control_12_I11                     -0.141837                       0.0
# human_control_12_I12                      0.314277                       0.0
# human_deletion_47_I13                     0.047383                       0.0
# human_deletion_47_I14                     0.143547                       0.0
# human_control_5_I15                      -3.465404                       0.0
# human_control_5_I16                      -3.865392                       0.0
# human_deletion_40_I17                     0.175718                       0.0
# human_deletion_40_I18                     0.199871                       0.0
# human_deletion_27_I19                     0.353074                       0.0
# human_deletion_27_I20                     0.202879                       0.0
# human_deletion_42_I21                     0.145724                       0.0
# human_deletion_42_I22                     0.339127                       0.0
# human_control_19_I23                      0.238809                       0.0
# human_control_19_I24                      0.458925                       0.0
# isogenic_control_24_J01                  -1.025724                       0.0
# isogenic_control_24_J02                  -0.201224                       0.0
# human_deletion_38_J03                     0.120127                       0.0
# human_deletion_38_J04                     0.062641                       0.0
# human_deletion_44_J05                     0.064020                       0.0
# human_deletion_44_J06                     0.072650                       0.0
# human_deletion_47_J07                     0.119013                       0.0
# human_deletion_47_J08                     0.067164                       0.0
# human_control_20_J09                     -0.202441                       0.0
# human_control_20_J10                     -0.118686                       0.0
# human_control_12_J11                     -1.116310                       0.0
# human_control_12_J12                     -0.649754                       0.0
# human_deletion_47_J13                     0.079759                       0.0
# human_deletion_47_J14                     0.097250                       0.0
# human_control_5_J15                      -2.159630                       0.0
# human_control_5_J16                      -0.119820                       0.0
# human_deletion_40_J17                     0.254592                       0.0
# human_deletion_40_J18                     0.273746                       0.0
# human_deletion_27_J19                     0.182831                       0.0
# human_deletion_27_J20                     0.483894                       0.0
# human_deletion_42_J21                     0.371471                       0.0
# human_deletion_42_J22                     0.376145                       0.0
# human_control_19_J23                      0.022798                       0.0
# ...
# human_deletion_28_E24                            -0.377538
# human_deletion_27_F01                             0.826742
# human_deletion_27_F02                             0.711007
# human_deletion_41_F03                             2.649464
# human_deletion_41_F04                             1.854762
# human_deletion_32_F05                             0.209236
# human_deletion_32_F06                             0.326568
# human_deletion_46_F07                             2.225281
# human_deletion_46_F08                             1.932676
# human_control_1_F09                               0.054797
# human_control_1_F10                              -0.001273
# human_control_14_F13                              0.167404
# human_control_14_F14                             -0.118135
# human_control_9_F15                               1.922359
# human_control_9_F16                               1.677279
# isogenic_control_23_F17                           0.928061
# isogenic_control_23_F18                           1.267599
# human_control_22_F19                              0.473213
# human_control_22_F20                              0.508712
# human_control_3_F21                              -0.732708
# human_control_3_F22                              -0.700221
# human_deletion_28_F23                             0.153584
# human_deletion_28_F24                            -0.088908
# human_control_5_G01                               1.085675
# human_control_5_G02                               2.209508
# human_deletion_35_G03                            -1.435101
# human_deletion_35_G04                            -1.477544
# human_control_13_G05                             -0.256099
# human_control_13_G06                             -0.237656
# human_control_19_G07                             -0.458708
# human_control_19_G08                             -0.629418
# isogenic_control_24_G09                           2.420517
# isogenic_control_24_G10                           2.215722
# human_control_17_G11                              0.006766
# human_control_17_G12                              0.372245
# human_control_21_G13                              2.128310
# human_control_21_G14                              1.659731
# human_deletion_28_G15                             0.109663
# human_deletion_28_G16                            -0.076658
# human_deletion_31_G17                             2.013642
# human_deletion_31_G18                             2.489239
# human_control_10_G19                              0.905193
# human_control_10_G20                              0.361411
# human_deletion_45_G21                            -0.121279
# human_deletion_45_G22                            -0.315408
# human_control_11_G23                             -0.467094
# human_control_11_G24                             -0.613052
# human_control_5_H01                               1.777899
# human_control_5_H02                               0.293760
# human_deletion_35_H03                            -1.172953
# human_deletion_35_H04                            -1.205480
# human_control_13_H05                              0.537182
# human_control_13_H06                              0.369351
# human_control_19_H07                              0.215676
# human_control_19_H08                             -0.151410
# isogenic_control_24_H09                           3.033932
# isogenic_control_24_H10                           1.733808
# human_control_17_H11                              0.743592
# human_control_17_H12                              0.584239
# human_control_21_H13                              2.465625
# human_control_21_H14                              1.801842
# human_deletion_28_H15                             0.655458
# human_deletion_28_H16                            -0.143807
# human_deletion_31_H17                             3.420609
# human_deletion_31_H18                             1.834525
# human_control_10_H19                              0.893194
# human_control_10_H20                              0.109272
# human_deletion_45_H21                             0.330916
# human_deletion_45_H22                             0.069722
# human_control_11_H23                             -0.410901
# human_control_11_H24                             -0.382563
# isogenic_control_24_I01                           1.635462
# isogenic_control_24_I02                           1.385738
# human_deletion_38_I03                            -1.255154
# human_deletion_38_I04                            -1.226720
# human_deletion_44_I05                            -0.215536
# human_deletion_44_I06                            -0.306335
# human_deletion_47_I07                            -0.766121
# human_deletion_47_I08                            -0.939010
# human_control_20_I09                              0.404811
# human_control_20_I10                             -0.301329
# human_control_12_I11                             -0.881604
# human_control_12_I12                             -1.017858
# human_deletion_47_I13                            -1.055126
# human_deletion_47_I14                            -1.120146
# human_control_5_I15                               2.958304
# human_control_5_I16                               1.934541
# human_deletion_40_I17                            -0.916710
# human_deletion_40_I18                            -1.096434
# human_deletion_27_I19                             0.256623
# human_deletion_27_I20                             0.105653
# human_deletion_42_I21                            -0.164735
# human_deletion_42_I22                            -0.130980
# human_control_19_I23                             -0.631980
# human_control_19_I24                             -0.493617
# isogenic_control_24_J01                           0.458525
# isogenic_control_24_J02                           1.633206
# human_deletion_38_J03                            -0.785399
# human_deletion_38_J04                            -0.731546
# human_deletion_44_J05                             0.550241
# human_deletion_44_J06                             0.509944
# human_deletion_47_J07                            -0.457982
# human_deletion_47_J08                            -0.416829
# human_control_20_J09                              0.414956
# human_control_20_J10                             -0.071807
# human_control_12_J11                             -0.840571
# human_control_12_J12                             -0.739583
# human_deletion_47_J13                            -0.658110
# human_deletion_47_J14                            -0.748720
# human_control_5_J15                               2.258235
# human_control_5_J16                               1.774494
# human_deletion_40_J17                            -0.751735
# human_deletion_40_J18                            -0.846128
# human_deletion_27_J19                             0.010474
# human_deletion_27_J20                            -0.205485
# human_deletion_42_J21                            -0.049789
# human_deletion_42_J22                            -0.292407
# human_control_19_J23                             -0.581613
# human_control_19_J24                             -0.613405
# human_control_6_K01                               1.875475
# human_control_6_K02                               0.689709
# human_deletion_40_K03                            -1.045751
# human_deletion_40_K04                            -0.967746
# human_deletion_41_K05                             1.650505
# human_deletion_41_K06                             1.562602
# human_control_2_K07                              -0.315313
# human_control_2_K08                              -0.509210
# isogenic_deletion_26_K09                          1.853065
# isogenic_deletion_26_K10                          1.583321
# human_deletion_48_K11                            -1.074826
# human_deletion_48_K12                            -1.262442
# human_deletion_39_K13                             0.234437
# human_deletion_39_K14                            -0.150295
# human_deletion_48_K15                            -0.908314
# human_deletion_48_K16                            -0.952046
# human_deletion_30_K17                            -0.401499
# human_deletion_30_K18                            -0.634169
# human_control_8_K19                               1.854662
# human_control_8_K20                               1.610234
# human_deletion_46_K21                             0.685421
# human_deletion_46_K22                             0.303240
# human_deletion_32_K23                            -0.293537
# human_deletion_32_K24                            -0.370534
# human_control_6_L01                               1.267102
# human_control_6_L02                              -0.105127
# human_deletion_40_L03                            -0.208671
# human_deletion_40_L04                            -0.471180
# human_deletion_41_L05                             2.285077
# human_deletion_41_L06                             2.175022
# human_control_2_L07                               0.204333
# human_control_2_L08                              -0.410033
# isogenic_deletion_26_L09                          2.499836
# isogenic_deletion_26_L10                          1.478308
# human_deletion_48_L11                            -0.494531
# human_deletion_48_L12                            -0.938934
# human_deletion_39_L13                             0.768727
# human_deletion_39_L14                             0.125280
# human_deletion_48_L15                            -0.334923
# human_deletion_48_L16                            -0.708650
# human_deletion_30_L17                            -0.361277
# human_deletion_30_L18                            -0.383691
# human_control_8_L19                               1.827838
# human_control_8_L20                               1.471727
# human_deletion_46_L21                             0.766717
# human_deletion_46_L22                             0.550203
# human_deletion_32_L23                            -0.226141
# human_deletion_32_L24                            -0.426169
# human_control_14_M01                             -0.327556
# human_control_14_M02                             -0.381974
# human_deletion_36_M03                            -0.281720
# human_deletion_36_M04                            -0.315135
# human_deletion_43_M05                             0.656320
# human_deletion_43_M06                             1.050922
# human_control_16_M07                             -1.265004
# human_control_16_M08                             -1.231714
# human_deletion_45_M09                            -0.264266
# human_deletion_45_M10                            -0.259757
# human_control_4_M11                              -1.184137
# human_control_4_M12                              -1.036988
# isogenic_deletion_25_M13                          1.254885
# isogenic_deletion_25_M14                          0.806238
# human_deletion_34_M15                            -1.348837
# human_deletion_34_M16                            -1.300738
# human_deletion_44_M17                            -0.525553
# human_deletion_44_M18                            -0.410813
# human_control_15_M19                             -0.337821
# human_control_15_M20                             -0.359331
# human_deletion_37_M21                            -0.377001
# human_deletion_37_M22                            -0.280180
# human_control_7_M23                              -0.049075
# human_control_7_M24                               0.137742
# human_control_14_N01                             -0.096609
# human_control_14_N02                             -0.304768
# human_deletion_36_N03                             0.333545
# human_deletion_36_N04                             0.115043
# human_deletion_43_N05                             1.461328
# human_deletion_43_N06                             0.950914
# human_control_16_N07                             -0.984814
# human_control_16_N08                             -0.932645
# human_deletion_45_N09                             0.293050
# human_deletion_45_N10                             0.156557
# human_control_4_N11                              -0.990997
# human_control_4_N12                              -0.957151
# isogenic_deletion_25_N13                          1.644785
# isogenic_deletion_25_N14                          0.921311
# human_deletion_34_N15                            -1.047862
# human_deletion_34_N16                            -1.008908
# human_deletion_44_N17                            -0.206565
# human_deletion_44_N18                            -0.199888
# human_control_15_N19                             -0.205941
# human_control_15_N20                             -0.349298
# human_deletion_37_N21                            -0.219103
# human_deletion_37_N22                            -0.175062
# human_control_7_N23                               0.007825
# human_control_7_N24                              -0.096805
# human_control_10_O01                             -0.211413
# human_control_10_O02                             -0.569535
# isogenic_deletion_25_O03                          0.724656
# isogenic_deletion_25_O04                          0.684529
# human_control_8_O05                               0.802052
# human_control_8_O06                               0.433314
# human_deletion_31_O07                             0.081838
# human_deletion_31_O08                             0.239446
# human_control_18_O09                             -0.956142
# human_control_18_O10                             -1.122745
# human_control_21_O11                              0.262956
# human_control_21_O12                              0.270712
# human_control_3_O13                              -1.070736
# human_control_3_O14                              -1.204646
# isogenic_control_23_O15                           0.150033
# isogenic_control_23_O16                          -0.283785
# human_deletion_33_O17                            -2.195906
# human_control_13_O19                             -0.786177
# human_control_13_O20                             -0.877786
# human_deletion_35_O21                            -1.371637
# human_deletion_35_O22                            -1.266367
# human_control_22_O23                             -0.687984
# human_control_22_O24                             -0.911555
# human_control_10_P01                              0.158627
# human_control_10_P02                             -0.390824
# isogenic_deletion_25_P03                          1.609258
# isogenic_deletion_25_P04                          1.038609
# human_control_8_P05                               1.144938
# human_control_8_P06                               0.419354
# human_deletion_31_P07                             0.226970
# human_deletion_31_P08                             0.026536
# human_control_18_P09                             -0.385263
# human_control_18_P10                             -0.568254
# human_control_21_P11                              0.876563
# human_control_21_P12                              0.433401
# human_control_3_P13                              -0.644044
# human_control_3_P14                              -1.182577
# isogenic_control_23_P15                           0.500233
# isogenic_control_23_P16                           0.414989
# human_deletion_33_P17                            -2.078828
# human_control_13_P19                             -0.596659
# human_control_13_P20                             -0.841695
# human_deletion_35_P21                            -1.190141
# human_deletion_35_P22                            -1.173465
# human_control_22_P23                             -0.611955
# human_control_22_P24                             -0.731574
#
# [380 rows x 4023 columns]

# %% [markdown]
# # Stdev selection

# %%
data_df = var_threshold_selection(data)

# %%
# %%time
data_df['group'] = data_df.index.str.split('_').map(lambda x: x[2])

# Remove high stdev features
# For each feature, get mean standrad dev
perturb_list = list(set(data_df['group'].tolist()))
feature_list = data_df.drop('group', axis=1).columns.tolist()
features_std_to_keep = []

keep_threshold = 0.5
mean_stdevs = []

for feature in feature_list:
    feature_stdevs = [] # list of stdevs per feature, should equal number of perturbations
    for perturb in perturb_list:
        temp = data_df[data_df['group'] == perturb][feature]
        temp_values = list(temp.values)
        feature_stdevs.append(np.std(temp_values))
    feature_mean_stdev = np.mean(feature_stdevs)
    mean_stdevs.append(feature_mean_stdev)
    if feature_mean_stdev < keep_threshold:
        features_std_to_keep.append(feature)
    # Reset feature stdevs for the next feature
    feature_stdevs = []
    
print(len(features_std_to_keep))

# %%
# %%time
# Null distribution for stdev features
perturb_list = list(set(data_df['group'].tolist()))
feature_list = data_df.drop('group', axis=1).columns.tolist()

# Shuffle the groups
groups = data_df['group'].tolist()
random.Random(4).shuffle(groups)
data_df['group'] = groups

mean_stdevs_null = []
for feature in feature_list:
    feature_stdevs = [] # list of stdevs per feature, should equal number of perturbations
    for perturb in perturb_list:
        temp = data_df[data_df['group'] == perturb][feature]
        temp_values = list(temp.values)
        feature_stdevs.append(np.std(temp_values))
    feature_mean_stdev = np.mean(feature_stdevs)
    mean_stdevs_null.append(feature_mean_stdev)
    # Reset feature stdevs for the next feature
    feature_stdevs = []

# %%
print(np.percentile(mean_stdevs_null, 8))
# distplot of the mean stdevs for each feature
fig, ax = plt.subplots(figsize=(12,5))
sns.distplot(mean_stdevs, ax=ax)
sns.distplot(mean_stdevs_null, ax=ax)
plt.xlabel('StDev')

plt.title('Mean Standard Deviation by Feature')

# %%
data_stdev = data_df[features_std_to_keep]
data_stdev

# %% [markdown]
# # Remove highly correlated features

# %%
# For a given feature name, get the grouped names
cat1 = ['Cells_AreaShape', 'Cytoplasm_AreaShape', 'Nuclei_AreaShape',
       'Cells_Neighbors', 'Cytoplasm_Neighbors', 'Nuclei_Neighbors',
       'Cells_Correlation', 'Cytoplasm_Correlation', 'Nuclei_Correlation']
cat2 = ['Location', 'Granularity', 'Texture', 'Intensity', 'RadialDistribution']

def get_group_feature_names(df, name_pruning_categories1, name_pruning_categories2):
    """
    features_df: the df of significant features with their values for a given gene or cluster
    categories1 is the AreaShape features ['Cells_AreaShape', 'Cells_Mean_A568Objects_AreaShape', 'Cells_Mean_Tubes_AreaShape', 
                           'Cytoplasm_AreaShape', 'Nuclei_AreaShape']
    categories2 is the other features ['Location', 'Granularity', 'Texture', 'Intensity', 'RadialDistribution']
    """
    if 'cluster_num' in df.columns:
        df = df.drop(['cluster_num'], axis=1)
    df = df.T
    df['split'] = df.index.str.split('_')
    df['group'] = ''
    channels = ['DNA', 'ER', 'Mito', 'RNA', 'AGP', 'Brightfield']
    # Categorize the AreaShape features
    for index, row in df.iterrows():
#         print(index)
        for name in name_pruning_categories1:
            if name in index:
                df.loc[index, 'group'] = name
        for name in name_pruning_categories2:
            for ch in channels:
                if name in row['split'] and ch in index[-30:]:
                    df.loc[index, 'group'] = name + '_' + ch

    return df

# %%
data_grouped = get_group_feature_names(data_stdev, cat1, cat2)
set(data_grouped['group'].tolist())

# %%
groups = data_grouped['group']
data_annotated = data_stdev.copy()
data_annotated.loc['metafeature'] = groups
data_annotated

# %%
# all tables
cells_AS = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Cells_AreaShape']].drop(['metafeature'], axis=0).astype('float64')
cyto_AS = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Cytoplasm_AreaShape']].drop(['metafeature'], axis=0).astype('float64')
nuc_AS = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Nuclei_AreaShape']].drop(['metafeature'], axis=0).astype('float64')

cells_corr = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Cells_Correlation']].drop(['metafeature'], axis=0).astype('float64')
cyto_corr = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Cytoplcorrm_Correlation']].drop(['metafeature'], axis=0).astype('float64')
nuc_corr = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Nuclei_Correlation']].drop(['metafeature'], axis=0).astype('float64')

cells_neighbors = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Cells_Neighbors']].drop(['metafeature'], axis=0).astype('float64')
cyto_neighbors = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Cytoplcorrm_Neighbors']].drop(['metafeature'], axis=0).astype('float64')
nuc_neighbors = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Nuclei_Neighbors']].drop(['metafeature'], axis=0).astype('float64')

agp_loc = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Location_AGP']].drop(['metafeature'], axis=0).astype('float64')
agp_gran = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Granularity_AGP']].drop(['metafeature'], axis=0).astype('float64')
agp_tex = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Texture_AGP']].drop(['metafeature'], axis=0).astype('float64')
agp_int = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Intensity_AGP']].drop(['metafeature'], axis=0).astype('float64')
agp_rdist = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='RadialDistribution_AGP']].drop(['metafeature'], axis=0).astype('float64')

Brightfield_loc = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Location_Brightfield']].drop(['metafeature'], axis=0).astype('float64')
Brightfield_gran = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Granularity_Brightfield']].drop(['metafeature'], axis=0).astype('float64')
Brightfield_tex = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Texture_Brightfield']].drop(['metafeature'], axis=0).astype('float64')
Brightfield_int = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Intensity_Brightfield']].drop(['metafeature'], axis=0).astype('float64')
Brightfield_rdist = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='RadialDistribution_Brightfield']].drop(['metafeature'], axis=0).astype('float64')

dna_loc = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Location_DNA']].drop(['metafeature'], axis=0).astype('float64')
dna_gran = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Granularity_DNA']].drop(['metafeature'], axis=0).astype('float64')
dna_tex = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Texture_DNA']].drop(['metafeature'], axis=0).astype('float64')
dna_int = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Intensity_DNA']].drop(['metafeature'], axis=0).astype('float64')
dna_rdist = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='RadialDistribution_DNA']].drop(['metafeature'], axis=0).astype('float64')

ER_loc = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Location_ER']].drop(['metafeature'], axis=0).astype('float64')
ER_gran = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Granularity_ER']].drop(['metafeature'], axis=0).astype('float64')
ER_tex = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Texture_ER']].drop(['metafeature'], axis=0).astype('float64')
ER_int = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Intensity_ER']].drop(['metafeature'], axis=0).astype('float64')
ER_rdist = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='RadialDistribution_ER']].drop(['metafeature'], axis=0).astype('float64')

Mito_loc = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Location_Mito']].drop(['metafeature'], axis=0).astype('float64')
Mito_gran = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Granularity_Mito']].drop(['metafeature'], axis=0).astype('float64')
Mito_tex = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Texture_Mito']].drop(['metafeature'], axis=0).astype('float64')
Mito_int = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Intensity_Mito']].drop(['metafeature'], axis=0).astype('float64')
Mito_rdist = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='RadialDistribution_Mito']].drop(['metafeature'], axis=0).astype('float64')

RNA_loc = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Location_RNA']].drop(['metafeature'], axis=0).astype('float64')
RNA_gran = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Granularity_RNA']].drop(['metafeature'], axis=0).astype('float64')
RNA_tex = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Texture_RNA']].drop(['metafeature'], axis=0).astype('float64')
RNA_int = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='Intensity_RNA']].drop(['metafeature'], axis=0).astype('float64')
RNA_rdist = data_annotated[data_annotated.columns[data_annotated.loc['metafeature']=='RadialDistribution_RNA']].drop(['metafeature'], axis=0).astype('float64')

# %%
tables = [cells_AS, cyto_AS, nuc_AS,
         cells_neighbors, cyto_neighbors, nuc_neighbors,
         cells_corr, cyto_corr, nuc_corr,
         agp_loc, agp_gran, agp_tex, agp_int, agp_rdist,
         Brightfield_loc,Brightfield_gran, Brightfield_tex, Brightfield_int, Brightfield_rdist,
         dna_loc, dna_gran, dna_tex, dna_int, dna_rdist,
         ER_loc, ER_gran, ER_tex, ER_int, ER_rdist,
         Mito_loc,Mito_gran, Mito_tex, Mito_int, Mito_rdist,
         RNA_loc, RNA_gran, RNA_tex, RNA_int, RNA_rdist]
ct = 0
for i in tables:
    ct+= i.shape[1]    
ct

# %%
feature_selected = pd.DataFrame(index=data_stdev.index)

for i in tables:
    corr_selected = corr_threshold_selection(i, 0.9)
    feature_selected = pd.concat([feature_selected, corr_selected], axis=1)

feature_selected

# %%
# feature_selected.to_csv('C:/Users/Ruifan/neuronal-cell-painting/feature_sets/Progenitors/0714_stdev_corr_fs.csv')
